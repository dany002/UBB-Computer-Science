# %% [markdown]
# # Computer Vision and Deep Learning - Laboratory 3
#
# In this laboratory session, we'll be diving into deep convolutional neural networks.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt


import torch
import torchvision
import torchvision.transforms as transforms

# %%
# !wget https://www.math.hkust.edu.hk/~masyleung/Teaching/CAS/MATLAB/image/images/cameraman.jpg
# Out:
# --2023-11-09 14:03:17--  https://www.math.hkust.edu.hk/~masyleung/Teaching/CAS/MATLAB/image/images/cameraman.jpg
# Resolving www.math.hkust.edu.hk (www.math.hkust.edu.hk)... 143.89.17.184
# Connecting to www.math.hkust.edu.hk (www.math.hkust.edu.hk)|143.89.17.184|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12170 (12K) [image/jpeg]
# Saving to: ‘cameraman.jpg’
#
# cameraman.jpg       100%[===================>]  11.88K  --.-KB/s    in 0s
#
# 2023-11-09 14:03:18 (122 MB/s) - ‘cameraman.jpg’ saved [12170/12170]

# %% [markdown]
# # Warm-up
#
#
# Let's start by implementing the basic blocks of a convolutional neural network: the convolutional and (optional) the pooling operations. This would be the last "low-level" implementation that you'll do for this class.
#
# ## Convolutions
#
# The convolutional layer is the main building block of a convolutional neural network. These layers contain a set of learnable filters, which will learn which features are relevant for the classification problem based on the training data.
# During the forward pass, each filter (which __must__ have the same depth as the input volume) is slided over the spatial dimensions of the input volume and we compute an element-wise multiplication between the filter weights and the region of interest in the input volume that lies beneath the filter.
#
# The hyperparameters of a convolutional layer are:
# - the filter size F (usually this is an odd value);
# - the padding amount which will be added to the input volume P;
# - the stride S (or the step used when sliding across the input volume);
# - the number of filters k; the depth of each filter must match the depth of the input volume;
#
# Given an input volume of shape  ($H_i$, $W_i$, $D$), the convolutional layer will produce an output of shape ($H_o$, $W_o$, $k$), where:
#
# \begin{equation}
# W_o = \frac{W_i - F + 2P}{S} + 1
# \end{equation}
#
# \begin{equation}
# H_o = \frac{H_i - F + 2P}{S} + 1
# \end{equation}
#
# <img src="https://lh6.googleusercontent.com/gZxwFH6mQ5tPjz6LzVbOaNeVuR1NC-BnuemIWO41qnn7r1PvP4qzwXRWC1OJgo2_PD08qaqJ2-VCF3q9laeK885IJwK-dHhpLDkvRZrx4vxrbLDTsKD2iZYM5SFRq4A6XTklk7_h"/>

# %%
def zero_pad(X, pad):
  """
  This function applies the zero padding operation on all the images in the array X
  :param X input array of images; this array has a of rank 4 (batch_size, height, width, channels)
  :param pad the amount of zeros to be added around around the spatial size of the images
  """
  # hint you might find the function numpy.pad useful for this purpose
  # keep in mind that you only need to pad the spatial dimensions (height and width)
  # TODO your code here
  X = np.pad(X, ((0,0), (pad, pad), (pad, pad), (0,0)), 'constant', constant_values=(0))
  return X

# load the image using Pillow
img = cv2.imread('cameraman.jpg', cv2.IMREAD_GRAYSCALE)
img = np.asarray(img)
img = img.reshape(1, img.shape[0], img.shape[1], 1)
padded_image = zero_pad(img, 10)
# TODO your code here
# pad and display the cameraman.jpg image
# (if you are using matplotlib to display the image, use cmap='gray' in the imshow function)
plt.imshow(padded_image[0], cmap='gray')

# %%
def convolution(X, W, bias, pad, stride):
  """
  This function applied to convolution operation on the input X of shape (num_samples, iH, iW, iC)
  using the filters defined by the W (filter weights) and  (bias) parameters.

  :param X - input of shape (num_samples, iH, iW, iC)
  :param W - weights, numpy array of shape (fs, fs, iC, k), where fs is the filter size,
    iC is the depth of the input volum and k is the number of filters applied on the image
  :param biases - numpy array of shape (1, 1, 1, k)
  :param pad - hyperparameter, the amount of padding to be applied
  :param stride - hyperparameter, the stride of the convolution
  """

  # 0. compute the size of the output activation map and initialize it with zeros

  num_samples = X.shape[0]
  iW = X.shape[2]
  iH = X.shape[1]
  f = W.shape[0]
  # TODO your code here
  # compute the output width (oW), height (oH) and number of channels (oC)
  oW = (iW - f + 2 * pad) // stride + 1
  oH = (iH - f + 2 * pad) // stride + 1
  oC = bias.shape[3]
  # initialize the output activation map with zeros
  activation_map = np.zeros((num_samples, oH, oW, oC))
  # end TODO your code here

  # 1. pad the samples in the input
  # TODO your code here, pad X using pad amount
  X_padded = zero_pad(X, pad)
  # end TODO your code here

  # go through each input sample
  for i in range(num_samples):
    # TODO: get the current sample from the input (use X_padded)
    X_i = X_padded[i]
    # end TODO your code here

    # loop over the spatial dimensions
    for y in range(oH):
      # TODO your code here
      # compute the current ROI in the image on which the filter will be applied (y dimension)
      # tl_y - the y coordinate of the top left corner of the current region
      # br_y - the y coordinate of the bottom right corner of the current region
      tl_y = y * stride
      br_y = y * stride + f
      # end TODO your code here

      for x in range(oW):
        # TODO your code here
        # compute the current ROI in the image on which the filter will be applied (x dimension)
        # tl_x - the x coordinate of the top left corner of the current region
        # br_x - the x coordinate of the bottom right corner of the current region
        tl_x = x * stride
        br_x = x * stride + f
        # end TODO your code here

        for c in range(oC):
            # select the current ROI on which the filter will be applied
            roi = X_padded[i, tl_y: br_y, tl_x: br_x, :]
            w = W[:, :, :, c]
            b = bias[:, :, :, c]

            # TODO your code here
            # apply the filter with the weights w and bias b on the current image roi

            # A. compute the elemetwise product between roi and the weights of the filters (np.multiply)
            a = np.multiply(w, roi)
            # B. sum across all the elements of a
            a = a.sum()
            # C. add the bias term
            a = a + b

            # D. add the result in the appropriate position of the output activation map
            activation_map[i, y, x, c] = a
            # end TODO your code here
        assert(activation_map.shape == (num_samples, oH, oW, oC))
  return activation_map



np.random.seed(10)
# 100 samples of shape (13, 21, 4)
X = np.random.randn(100, 13, 21, 4)

# 8 filters (last dimension) of shape (3, 3)
W = np.random.randn(3, 3, 4, 8)
b = np.random.randn(1, 1, 1, 8)

am = convolution(X, W, b, pad=1, stride=2)
print("am's mean =\n", np.mean(am))
print("am[1, 2, 3] =\n", am[3,2,1])
# Out:
# am's mean =
#  -0.4284130223223714
# am[1, 2, 3] =
#  [ 1.78081902 -6.51813947 -4.35815226 -2.91158344  1.84016713 -3.72264278
#  -8.32761753 -3.22778695]

# %% [markdown]
# Expected output:
#
# am's mean =
#  -0.42841306
#
# am[1, 2, 3] =
#  [ 1.780819  -6.5181394 -4.3581524 -2.9115834  1.8401672 -3.722643
#  -8.327618  -3.227787 ]

# %% [markdown]
# Now let's analyse the effect of applying some well known filters used in image processing.
#
# ### Low pass filters
# Low pass filters are used to keep the low frequency information within an, while reducing the high frequency information. These filters are the basis of image smoothing.
#
# Two well known low pass filters are the _mean filter_ and the _Gaussian filter_.

# %%
image = cv2.imread('cameraman.jpg', cv2.IMREAD_GRAYSCALE)
image = np.expand_dims(image, axis=-1)

# X contains a single image sample
X = np.expand_dims(image, axis=0)

plt.imshow(image, cmap='gray')

# %%
############################################################
# MEAN FILTER
############################################################

bias = np.asarray([0])
bias = bias.reshape((1, 1, 1, 1))

mean_filter_3 = np.ones(shape=(3, 3, 1, 1), dtype=np.float32)
mean_filter_3 = mean_filter_3/9.0

mean_filter_9 = np.ones(shape=(9, 9, 1, 1), dtype=np.float32)
mean_filter_9 = mean_filter_9/81.0

mean_3x3 = convolution(X, mean_filter_3, bias, pad=0, stride=1)
mean_9x9 = convolution(X, mean_filter_9, bias, pad=0, stride=1)

plt.figure(0)
plt.subplot(1, 2, 1)
plt.imshow(image[:, :, 0], cmap='gray')
plt.title('Original image')
plt.subplot(1, 2, 2)
plt.imshow(mean_3x3[0, :, :, 0], cmap='gray')
plt.title('mean filter 3x3')

plt.figure(2)
plt.subplot(1, 2, 1)
plt.imshow(image[:, :, 0], cmap='gray')
plt.title('Original image')
plt.subplot(1, 2, 2)
plt.imshow(mean_9x9[0, :, :, 0], cmap='gray')
plt.title('mean filter 9x9')


############################################################
# GAUSSIAN FILTER
############################################################

gaussian_filter = np.asarray(
    [[1, 2, 1],
     [2, 4, 2],
     [1, 2, 1]],
     dtype=np.float32
)
gaussian_filter = gaussian_filter.reshape(3, 3, 1, 1)
gaussian_filter = gaussian_filter/16.0

gaussian_smoothed = convolution(X, gaussian_filter, bias, pad=0, stride=1)

plt.figure(3)
plt.subplot(1, 2, 1)
plt.imshow(image[:, :, 0], cmap='gray')
plt.title('Original image')
plt.subplot(1, 2, 2)
plt.imshow(gaussian_smoothed[0,:,:,0], cmap='gray')
plt.title('Gaussian filtered')
# Out:
# Text(0.5, 1.0, 'Gaussian filtered')

# %% [markdown]
# __Optional__: Now load a color image and apply the mean filtering and Gaussian filtering on this color image.
# Not much changes at the call of the convolution operation, you just need to "play" with the convolutional kernels configurations.

# %%
# TODO your code here

# %% [markdown]
# ### High pass filters
#
# On the other hand, high pass filters are used to highlight the high frequency information in an image (edges, abrupt changes in intensities).
#
# One of the most commonly used high pass filters is the Sobel kernel (depicted below). These filters can be seen as discrete differentiation operators, and they compute an approximation of the gradient (on the horizontal or vertical direction) of the image intensity function.
#
# <img src="https://i.ytimg.com/vi/W7OpxFbrD84/maxresdefault.jpg" width=300px/>

# %%
sobel_horiz = np.asarray([[-1, 0, 1],
                          [-2, 0, 2],
                          [-1, 0, 1]])

sobel_vert = sobel_horiz.T

sobel_horiz = np.reshape(sobel_horiz, (3, 3, 1, 1))
sobel_vert = np.reshape(sobel_vert, (3, 3, 1, 1))

sobel_x = convolution(X, sobel_horiz, bias, 0, 1)
sobel_y = convolution(X, sobel_vert, bias, 0, 1)


plt.subplot(1, 3, 1)
plt.imshow(image[:, :, 0], cmap='gray')
plt.title('Original image')
plt.subplot(1, 3, 2)
plt.imshow(np.abs(sobel_x[0,:,:,0])/np.abs(np.max(sobel_x[0,:,:,0]))*255, cmap='gray')
plt.title('Sobel X')
plt.subplot(1, 3, 3)
plt.imshow(np.abs(sobel_y[0,:,:,0])/np.abs(np.max(sobel_y[0,:,:,0]))*255, cmap='gray')
plt.title('Sobel Y')
plt.tight_layout()

# %% [markdown]
# # Convolutional Neural Networks in pytorch
#
#
# In this laboratory, you'll be using convolutional neural networks (CNNs) to perform image classification in torch.
# You'll follow two approaches:
# - First, you'll design, implement, and train a simple network **from scratch**. However, in practice, you won't get to train an entire CNN from scratch (with random initialization), because it is relatively rare to have a dataset of sufficient size. Instead, the norm is to pre-train a CNN on a very large dataset and then use these weights as an initialization or a fixed feature extractor for the task of interest (transfer learning).
# - Therefore, in the second part you'll use **transfer learning** to fine-tune an already trained model on your dataset. Transfer learning is a machine learning technique where a model pre-trained on one task is adapted to a different, but related, task. This approach leverages the knowledge and features learned during the initial training to improve performance and reduce data requirements for the new task, making it more efficient and effective.
#
#
# The main pipeline when training a neural network model is:
# 1. "Get one with the data". Analyze your input images,
# 2. Define the model (start with something simple in the beginning)
# 3. Define the training setup
# 4. Train the model
# 5. Test and *analyze* the results.
# *Repeat the steps 2-5*
#
#
# # 1. Datasets and data loaders
#
#
# You will be working with the [Oxford-IIIT Pet Dataset](https://www.robots.ox.ac.uk/~vgg/data/pets/), which is a 37 category pet dataset with roughly 200 images for each class. The images have large variations in scale, pose, and lighting, and they are annotated with the breed of the pet (37 classes), the head ROI, and pixel-level trimap segmentation.
#
#
# *Datasets* and *DataLoader* are the core pytorch data structures for interacting with your data. Ideally, you would want your data handling code to be completely decoupled from the model training and testing code (you'll often need to evaluate your model on different datasets).
#
#
# ``torch.utils.data.Dataset`` stores the actual information about the dataset (the samples and their corresponding ground truth labels), while the torch.``utils.data.DataLoader`` wraps an iterable around the dataset, allowing easy access to the data, automatic batching, and multi-process data loading).
#
#
# For now, you'll use the OxfordPets dataset implementation from [torchvision](https://pytorch.org/vision/stable/generated/torchvision.datasets.OxfordIIITPet.html), but next time you'll be learning how you can create your own custom dataset and how to configure data loaders.
# torchvision is a popular package that comprises popular datasets, model architectures, and common image transformations for computer vision.
#
#
# Transforms are common image transformations available in the ``torchvision.transforms`` module and can be used to preprocess and augment the input data. They can be chained together using *Compose*.
# You can also use it to augment your data.
# Image augmentation generates similar but distinct training examples after a series of random changes to the training images, and can help reduce overfitting.
#
#
#
#
# ```
# transform = transforms.Compose(
#     [transforms.ToTensor(),
#      transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])
#
#
# ```

# %%
# TODO you code here
# - create an object of type torchvision.datasets.OxfordIIITPet, download it
# - torch.utils.data.DataLoader object
# - display some samples
import os
from torch.utils.data import Dataset, DataLoader
working_dir = "./"

pets_path_train = os.path.join(working_dir, 'OxfordPets', 'train')
pets_path_test = os.path.join(working_dir, 'OxfordPets', 'test')
pets_train_orig = torchvision.datasets.OxfordIIITPet(root=pets_path_train, split="trainval", target_types="segmentation", download=True)
pets_test_orig = torchvision.datasets.OxfordIIITPet(root=pets_path_test, split="test", target_types="segmentation", download=True)
train_dataloader = DataLoader(pets_train_orig, batch_size=64, shuffle=True)
test_dataloader = DataLoader(pets_test_orig, batch_size=64, shuffle=True)

# %%
# !ls -lah OxfordPets/test/oxford-iiit-pet/images/
# Out:
# Datele de ieșire de afișat au fost trunchiate la ultimele 5000 linii.
# -rwxr-xr-x 1 1001 1001  28K Jun 18  2012 Egyptian_Mau_91.jpg
# -rwxr-xr-x 1 1001 1001  31K Jun 18  2012 Egyptian_Mau_92.jpg
# -rwxr-xr-x 1 1001 1001  12K Jun 18  2012 Egyptian_Mau_93.jpg
# -rwxr-xr-x 1 1001 1001  13K Jun 18  2012 Egyptian_Mau_94.jpg
# -rwxr-xr-x 1 1001 1001  25K Jun 18  2012 Egyptian_Mau_95.jpg
# -rwxr-xr-x 1 1001 1001  23K Jun 18  2012 Egyptian_Mau_96.jpg
# -rwxr-xr-x 1 1001 1001 178K Jun 18  2012 Egyptian_Mau_97.jpg
# -rwxr-xr-x 1 1001 1001 8.6K Jun 18  2012 Egyptian_Mau_98.jpg
# -rwxr-xr-x 1 1001 1001  13K Jun 18  2012 Egyptian_Mau_99.jpg
# -rwxr-xr-x 1 1001 1001  48K Jun 18  2012 Egyptian_Mau_9.jpg
# -rwxr-xr-x 1 1001 1001 161K Jun 18  2012 english_cocker_spaniel_100.jpg
# -rwxr-xr-x 1 1001 1001 167K Jun 18  2012 english_cocker_spaniel_101.jpg
# -rwxr-xr-x 1 1001 1001 236K Jun 18  2012 english_cocker_spaniel_102.jpg
# -rwxr-xr-x 1 1001 1001  84K Jun 18  2012 english_cocker_spaniel_103.jpg
# -rwxr-xr-x 1 1001 1001 163K Jun 18  2012 english_cocker_spaniel_104.jpg
# -rwxr-xr-x 1 1001 1001 166K Jun 18  2012 english_cocker_spaniel_105.jpg
# -rwxr-xr-x 1 1001 1001 128K Jun 18  2012 english_cocker_spaniel_106.jpg
# -rwxr-xr-x 1 1001 1001 178K Jun 18  2012 english_cocker_spaniel_107.jpg
# -rwxr-xr-x 1 1001 1001 146K Jun 18  2012 english_cocker_spaniel_108.jpg
# -rwxr-xr-x 1 1001 1001  87K Jun 18  2012 english_cocker_spaniel_109.jpg
# -rwxr-xr-x 1 1001 1001  85K Jun 18  2012 english_cocker_spaniel_10.jpg
# -rwxr-xr-x 1 1001 1001 110K Jun 18  2012 english_cocker_spaniel_110.jpg
# -rwxr-xr-x 1 1001 1001  66K Jun 18  2012 english_cocker_spaniel_111.jpg
# -rwxr-xr-x 1 1001 1001 112K Jun 18  2012 english_cocker_spaniel_112.jpg
# -rwxr-xr-x 1 1001 1001 120K Jun 18  2012 english_cocker_spaniel_113.jpg
# -rwxr-xr-x 1 1001 1001 142K Jun 18  2012 english_cocker_spaniel_114.jpg
# -rwxr-xr-x 1 1001 1001 126K Jun 18  2012 english_cocker_spaniel_115.jpg
# -rwxr-xr-x 1 1001 1001 141K Jun 18  2012 english_cocker_spaniel_116.jpg
# -rwxr-xr-x 1 1001 1001 100K Jun 18  2012 english_cocker_spaniel_117.jpg
# -rwxr-xr-x 1 1001 1001  86K Jun 18  2012 english_cocker_spaniel_118.jpg
# -rwxr-xr-x 1 1001 1001 123K Jun 18  2012 english_cocker_spaniel_119.jpg
# -rwxr-xr-x 1 1001 1001 153K Jun 18  2012 english_cocker_spaniel_11.jpg
# -rwxr-xr-x 1 1001 1001 104K Jun 18  2012 english_cocker_spaniel_120.jpg
# -rwxr-xr-x 1 1001 1001 133K Jun 18  2012 english_cocker_spaniel_121.jpg
# -rwxr-xr-x 1 1001 1001 179K Jun 18  2012 english_cocker_spaniel_122.jpg
# -rwxr-xr-x 1 1001 1001  34K Jun 18  2012 english_cocker_spaniel_123.jpg
# -rwxr-xr-x 1 1001 1001 124K Jun 18  2012 english_cocker_spaniel_124.jpg
# -rwxr-xr-x 1 1001 1001  99K Jun 18  2012 english_cocker_spaniel_125.jpg
# -rwxr-xr-x 1 1001 1001 115K Jun 18  2012 english_cocker_spaniel_126.jpg
# -rwxr-xr-x 1 1001 1001 181K Jun 18  2012 english_cocker_spaniel_127.jpg
# -rwxr-xr-x 1 1001 1001 103K Jun 18  2012 english_cocker_spaniel_128.jpg
# -rwxr-xr-x 1 1001 1001 151K Jun 18  2012 english_cocker_spaniel_129.jpg
# -rwxr-xr-x 1 1001 1001  77K Jun 18  2012 english_cocker_spaniel_12.jpg
# -rwxr-xr-x 1 1001 1001 134K Jun 18  2012 english_cocker_spaniel_130.jpg
# -rwxr-xr-x 1 1001 1001 129K Jun 18  2012 english_cocker_spaniel_131.jpg
# -rwxr-xr-x 1 1001 1001  86K Jun 18  2012 english_cocker_spaniel_132.jpg
# -rwxr-xr-x 1 1001 1001  85K Jun 18  2012 english_cocker_spaniel_133.jpg
# -rwxr-xr-x 1 1001 1001 136K Jun 18  2012 english_cocker_spaniel_134.jpg
# -rwxr-xr-x 1 1001 1001 169K Jun 18  2012 english_cocker_spaniel_135.jpg
# -rwxr-xr-x 1 1001 1001  96K Jun 18  2012 english_cocker_spaniel_136.jpg
# -rwxr-xr-x 1 1001 1001 155K Jun 18  2012 english_cocker_spaniel_137.jpg
# -rwxr-xr-x 1 1001 1001 130K Jun 18  2012 english_cocker_spaniel_138.jpg
# -rwxr-xr-x 1 1001 1001 198K Jun 18  2012 english_cocker_spaniel_139.jpg
# -rwxr-xr-x 1 1001 1001 102K Jun 18  2012 english_cocker_spaniel_13.jpg
# -rwxr-xr-x 1 1001 1001 143K Jun 18  2012 english_cocker_spaniel_140.jpg
# -rwxr-xr-x 1 1001 1001 175K Jun 18  2012 english_cocker_spaniel_141.jpg
# -rwxr-xr-x 1 1001 1001 241K Jun 18  2012 english_cocker_spaniel_142.jpg
# -rwxr-xr-x 1 1001 1001 155K Jun 18  2012 english_cocker_spaniel_143.jpg
# -rwxr-xr-x 1 1001 1001  80K Jun 18  2012 english_cocker_spaniel_144.jpg
# -rwxr-xr-x 1 1001 1001 114K Jun 18  2012 english_cocker_spaniel_145.jpg
# -rwxr-xr-x 1 1001 1001 110K Jun 18  2012 english_cocker_spaniel_146.jpg
# -rwxr-xr-x 1 1001 1001 109K Jun 18  2012 english_cocker_spaniel_147.jpg
# -rwxr-xr-x 1 1001 1001 152K Jun 18  2012 english_cocker_spaniel_148.jpg
# -rwxr-xr-x 1 1001 1001 175K Jun 18  2012 english_cocker_spaniel_149.jpg
# -rwxr-xr-x 1 1001 1001  83K Jun 18  2012 english_cocker_spaniel_14.jpg
# -rwxr-xr-x 1 1001 1001  91K Jun 18  2012 english_cocker_spaniel_150.jpg
# -rwxr-xr-x 1 1001 1001  99K Jun 18  2012 english_cocker_spaniel_151.jpg
# -rwxr-xr-x 1 1001 1001  84K Jun 18  2012 english_cocker_spaniel_152.jpg
# -rwxr-xr-x 1 1001 1001 156K Jun 18  2012 english_cocker_spaniel_153.jpg
# -rwxr-xr-x 1 1001 1001 152K Jun 18  2012 english_cocker_spaniel_154.jpg
# -rwxr-xr-x 1 1001 1001 121K Jun 18  2012 english_cocker_spaniel_155.jpg
# -rwxr-xr-x 1 1001 1001 130K Jun 18  2012 english_cocker_spaniel_156.jpg
# -rwxr-xr-x 1 1001 1001 115K Jun 18  2012 english_cocker_spaniel_157.jpg
# -rwxr-xr-x 1 1001 1001  98K Jun 18  2012 english_cocker_spaniel_158.jpg
# -rwxr-xr-x 1 1001 1001 108K Jun 18  2012 english_cocker_spaniel_159.jpg
# -rwxr-xr-x 1 1001 1001  87K Jun 18  2012 english_cocker_spaniel_15.jpg
# -rwxr-xr-x 1 1001 1001 119K Jun 18  2012 english_cocker_spaniel_160.jpg
# -rwxr-xr-x 1 1001 1001  86K Jun 18  2012 english_cocker_spaniel_161.jpg
# -rwxr-xr-x 1 1001 1001  99K Jun 18  2012 english_cocker_spaniel_162.jpg
# -rwxr-xr-x 1 1001 1001  84K Jun 18  2012 english_cocker_spaniel_163.jpg
# -rwxr-xr-x 1 1001 1001 152K Jun 18  2012 english_cocker_spaniel_164.jpg
# -rwxr-xr-x 1 1001 1001 126K Jun 18  2012 english_cocker_spaniel_165.jpg
# -rwxr-xr-x 1 1001 1001 134K Jun 18  2012 english_cocker_spaniel_166.jpg
# -rwxr-xr-x 1 1001 1001 115K Jun 18  2012 english_cocker_spaniel_167.jpg
# -rwxr-xr-x 1 1001 1001 117K Jun 18  2012 english_cocker_spaniel_168.jpg
# -rwxr-xr-x 1 1001 1001 201K Jun 18  2012 english_cocker_spaniel_169.jpg
# -rwxr-xr-x 1 1001 1001 111K Jun 18  2012 english_cocker_spaniel_16.jpg
# -rwxr-xr-x 1 1001 1001 155K Jun 18  2012 english_cocker_spaniel_170.jpg
# -rwxr-xr-x 1 1001 1001 146K Jun 18  2012 english_cocker_spaniel_171.jpg
# -rwxr-xr-x 1 1001 1001 143K Jun 18  2012 english_cocker_spaniel_172.jpg
# -rwxr-xr-x 1 1001 1001 118K Jun 18  2012 english_cocker_spaniel_173.jpg
# -rwxr-xr-x 1 1001 1001  28K Jun 18  2012 english_cocker_spaniel_174.jpg
# -rwxr-xr-x 1 1001 1001  72K Jun 18  2012 english_cocker_spaniel_175.jpg
# -rwxr-xr-x 1 1001 1001  56K Jun 18  2012 english_cocker_spaniel_176.jpg
# -rwxr-xr-x 1 1001 1001  94K Jun 18  2012 english_cocker_spaniel_177.jpg
# -rwxr-xr-x 1 1001 1001  81K Jun 18  2012 english_cocker_spaniel_178.jpg
# -rwxr-xr-x 1 1001 1001  56K Jun 18  2012 english_cocker_spaniel_179.jpg
# -rwxr-xr-x 1 1001 1001 168K Jun 18  2012 english_cocker_spaniel_17.jpg
# -rwxr-xr-x 1 1001 1001 118K Jun 18  2012 english_cocker_spaniel_180.jpg
# -rwxr-xr-x 1 1001 1001  97K Jun 18  2012 english_cocker_spaniel_181.jpg
# -rwxr-xr-x 1 1001 1001  86K Jun 18  2012 english_cocker_spaniel_182.jpg
# -rwxr-xr-x 1 1001 1001  55K Jun 18  2012 english_cocker_spaniel_183.jpg
# -rwxr-xr-x 1 1001 1001 140K Jun 18  2012 english_cocker_spaniel_184.jpg
# -rwxr-xr-x 1 1001 1001 154K Jun 18  2012 english_cocker_spaniel_185.jpg
# -rwxr-xr-x 1 1001 1001 152K Jun 18  2012 english_cocker_spaniel_186.jpg
# -rwxr-xr-x 1 1001 1001 136K Jun 18  2012 english_cocker_spaniel_187.jpg
# -rwxr-xr-x 1 1001 1001 161K Jun 18  2012 english_cocker_spaniel_188.jpg
# -rwxr-xr-x 1 1001 1001 144K Jun 18  2012 english_cocker_spaniel_189.jpg
# -rwxr-xr-x 1 1001 1001 189K Jun 18  2012 english_cocker_spaniel_18.jpg
# -rwxr-xr-x 1 1001 1001 141K Jun 18  2012 english_cocker_spaniel_190.jpg
# -rwxr-xr-x 1 1001 1001 145K Jun 18  2012 english_cocker_spaniel_191.jpg
# -rwxr-xr-x 1 1001 1001 174K Jun 18  2012 english_cocker_spaniel_192.jpg
# -rwxr-xr-x 1 1001 1001 174K Jun 18  2012 english_cocker_spaniel_193.jpg
# -rwxr-xr-x 1 1001 1001 177K Jun 18  2012 english_cocker_spaniel_194.jpg
# -rwxr-xr-x 1 1001 1001 187K Jun 18  2012 english_cocker_spaniel_195.jpg
# -rwxr-xr-x 1 1001 1001 164K Jun 18  2012 english_cocker_spaniel_196.jpg
# -rwxr-xr-x 1 1001 1001 125K Jun 18  2012 english_cocker_spaniel_197.jpg
# -rwxr-xr-x 1 1001 1001 136K Jun 18  2012 english_cocker_spaniel_198.jpg
# -rwxr-xr-x 1 1001 1001 141K Jun 18  2012 english_cocker_spaniel_199.jpg
# -rwxr-xr-x 1 1001 1001 180K Jun 18  2012 english_cocker_spaniel_19.jpg
# -rwxr-xr-x 1 1001 1001 115K Jun 18  2012 english_cocker_spaniel_1.jpg
# -rwxr-xr-x 1 1001 1001 108K Jun 18  2012 english_cocker_spaniel_200.jpg
# -rwxr-xr-x 1 1001 1001 132K Jun 18  2012 english_cocker_spaniel_20.jpg
# -rwxr-xr-x 1 1001 1001 132K Jun 18  2012 english_cocker_spaniel_21.jpg
# -rwxr-xr-x 1 1001 1001  91K Jun 18  2012 english_cocker_spaniel_22.jpg
# -rwxr-xr-x 1 1001 1001 100K Jun 18  2012 english_cocker_spaniel_23.jpg
# -rwxr-xr-x 1 1001 1001  72K Jun 18  2012 english_cocker_spaniel_24.jpg
# -rwxr-xr-x 1 1001 1001 134K Jun 18  2012 english_cocker_spaniel_25.jpg
# -rwxr-xr-x 1 1001 1001 108K Jun 18  2012 english_cocker_spaniel_26.jpg
# -rwxr-xr-x 1 1001 1001 119K Jun 18  2012 english_cocker_spaniel_27.jpg
# -rwxr-xr-x 1 1001 1001 117K Jun 18  2012 english_cocker_spaniel_28.jpg
# -rwxr-xr-x 1 1001 1001 129K Jun 18  2012 english_cocker_spaniel_29.jpg
# -rwxr-xr-x 1 1001 1001 122K Jun 18  2012 english_cocker_spaniel_2.jpg
# -rwxr-xr-x 1 1001 1001  79K Jun 18  2012 english_cocker_spaniel_30.jpg
# -rwxr-xr-x 1 1001 1001 130K Jun 18  2012 english_cocker_spaniel_31.jpg
# -rwxr-xr-x 1 1001 1001  92K Jun 18  2012 english_cocker_spaniel_32.jpg
# -rwxr-xr-x 1 1001 1001  90K Jun 18  2012 english_cocker_spaniel_33.jpg
# -rwxr-xr-x 1 1001 1001 119K Jun 18  2012 english_cocker_spaniel_34.jpg
# -rwxr-xr-x 1 1001 1001  94K Jun 18  2012 english_cocker_spaniel_35.jpg
# -rwxr-xr-x 1 1001 1001 153K Jun 18  2012 english_cocker_spaniel_36.jpg
# -rwxr-xr-x 1 1001 1001  85K Jun 18  2012 english_cocker_spaniel_37.jpg
# -rwxr-xr-x 1 1001 1001 200K Jun 18  2012 english_cocker_spaniel_38.jpg
# -rwxr-xr-x 1 1001 1001 162K Jun 18  2012 english_cocker_spaniel_39.jpg
# -rwxr-xr-x 1 1001 1001 163K Jun 18  2012 english_cocker_spaniel_3.jpg
# -rwxr-xr-x 1 1001 1001 212K Jun 18  2012 english_cocker_spaniel_40.jpg
# -rwxr-xr-x 1 1001 1001 163K Jun 18  2012 english_cocker_spaniel_41.jpg
# -rwxr-xr-x 1 1001 1001 133K Jun 18  2012 english_cocker_spaniel_42.jpg
# -rwxr-xr-x 1 1001 1001 126K Jun 18  2012 english_cocker_spaniel_43.jpg
# -rwxr-xr-x 1 1001 1001 213K Jun 18  2012 english_cocker_spaniel_44.jpg
# -rwxr-xr-x 1 1001 1001 203K Jun 18  2012 english_cocker_spaniel_45.jpg
# -rwxr-xr-x 1 1001 1001 140K Jun 18  2012 english_cocker_spaniel_46.jpg
# -rwxr-xr-x 1 1001 1001 133K Jun 18  2012 english_cocker_spaniel_47.jpg
# -rwxr-xr-x 1 1001 1001 159K Jun 18  2012 english_cocker_spaniel_48.jpg
# -rwxr-xr-x 1 1001 1001 211K Jun 18  2012 english_cocker_spaniel_49.jpg
# -rwxr-xr-x 1 1001 1001  92K Jun 18  2012 english_cocker_spaniel_4.jpg
# -rwxr-xr-x 1 1001 1001 102K Jun 18  2012 english_cocker_spaniel_50.jpg
# -rwxr-xr-x 1 1001 1001  91K Jun 18  2012 english_cocker_spaniel_51.jpg
# -rwxr-xr-x 1 1001 1001 112K Jun 18  2012 english_cocker_spaniel_52.jpg
# -rwxr-xr-x 1 1001 1001 210K Jun 18  2012 english_cocker_spaniel_53.jpg
# -rwxr-xr-x 1 1001 1001 123K Jun 18  2012 english_cocker_spaniel_54.jpg
# -rwxr-xr-x 1 1001 1001 137K Jun 18  2012 english_cocker_spaniel_55.jpg
# -rwxr-xr-x 1 1001 1001 150K Jun 18  2012 english_cocker_spaniel_56.jpg
# -rwxr-xr-x 1 1001 1001  94K Jun 18  2012 english_cocker_spaniel_57.jpg
# -rwxr-xr-x 1 1001 1001 154K Jun 18  2012 english_cocker_spaniel_58.jpg
# -rwxr-xr-x 1 1001 1001 214K Jun 18  2012 english_cocker_spaniel_59.jpg
# -rwxr-xr-x 1 1001 1001  90K Jun 18  2012 english_cocker_spaniel_5.jpg
# -rwxr-xr-x 1 1001 1001  71K Jun 18  2012 english_cocker_spaniel_60.jpg
# -rwxr-xr-x 1 1001 1001  68K Jun 18  2012 english_cocker_spaniel_61.jpg
# -rwxr-xr-x 1 1001 1001  92K Jun 18  2012 english_cocker_spaniel_62.jpg
# -rwxr-xr-x 1 1001 1001 107K Jun 18  2012 english_cocker_spaniel_63.jpg
# -rwxr-xr-x 1 1001 1001 140K Jun 18  2012 english_cocker_spaniel_64.jpg
# -rwxr-xr-x 1 1001 1001 142K Jun 18  2012 english_cocker_spaniel_65.jpg
# -rwxr-xr-x 1 1001 1001 116K Jun 18  2012 english_cocker_spaniel_66.jpg
# -rwxr-xr-x 1 1001 1001 142K Jun 18  2012 english_cocker_spaniel_67.jpg
# -rwxr-xr-x 1 1001 1001 101K Jun 18  2012 english_cocker_spaniel_68.jpg
# -rwxr-xr-x 1 1001 1001  78K Jun 18  2012 english_cocker_spaniel_69.jpg
# -rwxr-xr-x 1 1001 1001 125K Jun 18  2012 english_cocker_spaniel_6.jpg
# -rwxr-xr-x 1 1001 1001 198K Jun 18  2012 english_cocker_spaniel_70.jpg
# -rwxr-xr-x 1 1001 1001 166K Jun 18  2012 english_cocker_spaniel_71.jpg
# -rwxr-xr-x 1 1001 1001 209K Jun 18  2012 english_cocker_spaniel_72.jpg
# -rwxr-xr-x 1 1001 1001 114K Jun 18  2012 english_cocker_spaniel_73.jpg
# -rwxr-xr-x 1 1001 1001 169K Jun 18  2012 english_cocker_spaniel_74.jpg
# -rwxr-xr-x 1 1001 1001 213K Jun 18  2012 english_cocker_spaniel_75.jpg
# -rwxr-xr-x 1 1001 1001  76K Jun 18  2012 english_cocker_spaniel_76.jpg
# -rwxr-xr-x 1 1001 1001 195K Jun 18  2012 english_cocker_spaniel_77.jpg
# -rwxr-xr-x 1 1001 1001 321K Jun 18  2012 english_cocker_spaniel_78.jpg
# -rwxr-xr-x 1 1001 1001 135K Jun 18  2012 english_cocker_spaniel_79.jpg
# -rwxr-xr-x 1 1001 1001 159K Jun 18  2012 english_cocker_spaniel_7.jpg
# -rwxr-xr-x 1 1001 1001 104K Jun 18  2012 english_cocker_spaniel_80.jpg
# -rwxr-xr-x 1 1001 1001 153K Jun 18  2012 english_cocker_spaniel_81.jpg
# -rwxr-xr-x 1 1001 1001 140K Jun 18  2012 english_cocker_spaniel_82.jpg
# -rwxr-xr-x 1 1001 1001  72K Jun 18  2012 english_cocker_spaniel_83.jpg
# -rwxr-xr-x 1 1001 1001 105K Jun 18  2012 english_cocker_spaniel_84.jpg
# -rwxr-xr-x 1 1001 1001 140K Jun 18  2012 english_cocker_spaniel_85.jpg
# -rwxr-xr-x 1 1001 1001 109K Jun 18  2012 english_cocker_spaniel_86.jpg
# -rwxr-xr-x 1 1001 1001 109K Jun 18  2012 english_cocker_spaniel_87.jpg
# -rwxr-xr-x 1 1001 1001 122K Jun 18  2012 english_cocker_spaniel_88.jpg
# -rwxr-xr-x 1 1001 1001 152K Jun 18  2012 english_cocker_spaniel_89.jpg
# -rwxr-xr-x 1 1001 1001  75K Jun 18  2012 english_cocker_spaniel_8.jpg
# -rwxr-xr-x 1 1001 1001 200K Jun 18  2012 english_cocker_spaniel_90.jpg
# -rwxr-xr-x 1 1001 1001 177K Jun 18  2012 english_cocker_spaniel_91.jpg
# -rwxr-xr-x 1 1001 1001 127K Jun 18  2012 english_cocker_spaniel_92.jpg
# -rwxr-xr-x 1 1001 1001  95K Jun 18  2012 english_cocker_spaniel_93.jpg
# -rwxr-xr-x 1 1001 1001 136K Jun 18  2012 english_cocker_spaniel_94.jpg
# -rwxr-xr-x 1 1001 1001 153K Jun 18  2012 english_cocker_spaniel_95.jpg
# -rwxr-xr-x 1 1001 1001 187K Jun 18  2012 english_cocker_spaniel_96.jpg
# -rwxr-xr-x 1 1001 1001 152K Jun 18  2012 english_cocker_spaniel_97.jpg
# -rwxr-xr-x 1 1001 1001 153K Jun 18  2012 english_cocker_spaniel_98.jpg
# -rwxr-xr-x 1 1001 1001 125K Jun 18  2012 english_cocker_spaniel_99.jpg
# -rwxr-xr-x 1 1001 1001 108K Jun 18  2012 english_cocker_spaniel_9.jpg
# -rwxr-xr-x 1 1001 1001 135K Jun 18  2012 english_setter_100.jpg
# -rwxr-xr-x 1 1001 1001 146K Jun 18  2012 english_setter_101.jpg
# -rwxr-xr-x 1 1001 1001 133K Jun 18  2012 english_setter_102.jpg
# -rwxr-xr-x 1 1001 1001  83K Jun 18  2012 english_setter_103.jpg
# -rwxr-xr-x 1 1001 1001 148K Jun 18  2012 english_setter_104.jpg
# -rwxr-xr-x 1 1001 1001 113K Jun 18  2012 english_setter_105.jpg
# -rwxr-xr-x 1 1001 1001 112K Jun 18  2012 english_setter_106.jpg
# -rwxr-xr-x 1 1001 1001 197K Jun 18  2012 english_setter_107.jpg
# -rwxr-xr-x 1 1001 1001 109K Jun 18  2012 english_setter_108.jpg
# -rwxr-xr-x 1 1001 1001 112K Jun 18  2012 english_setter_109.jpg
# -rwxr-xr-x 1 1001 1001 114K Jun 18  2012 english_setter_10.jpg
# -rwxr-xr-x 1 1001 1001 121K Jun 18  2012 english_setter_110.jpg
# -rwxr-xr-x 1 1001 1001 163K Jun 18  2012 english_setter_111.jpg
# -rwxr-xr-x 1 1001 1001 144K Jun 18  2012 english_setter_112.jpg
# -rwxr-xr-x 1 1001 1001 114K Jun 18  2012 english_setter_113.jpg
# -rwxr-xr-x 1 1001 1001 127K Jun 18  2012 english_setter_114.jpg
# -rwxr-xr-x 1 1001 1001  44K Jun 18  2012 english_setter_115.jpg
# -rwxr-xr-x 1 1001 1001 120K Jun 18  2012 english_setter_116.jpg
# -rwxr-xr-x 1 1001 1001  92K Jun 18  2012 english_setter_117.jpg
# -rwxr-xr-x 1 1001 1001 114K Jun 18  2012 english_setter_118.jpg
# -rwxr-xr-x 1 1001 1001 123K Jun 18  2012 english_setter_119.jpg
# -rwxr-xr-x 1 1001 1001 101K Jun 18  2012 english_setter_11.jpg
# -rwxr-xr-x 1 1001 1001 105K Jun 18  2012 english_setter_120.jpg
# -rwxr-xr-x 1 1001 1001 103K Jun 18  2012 english_setter_121.jpg
# -rwxr-xr-x 1 1001 1001 120K Jun 18  2012 english_setter_122.jpg
# -rwxr-xr-x 1 1001 1001 193K Jun 18  2012 english_setter_123.jpg
# -rwxr-xr-x 1 1001 1001 167K Jun 18  2012 english_setter_124.jpg
# -rwxr-xr-x 1 1001 1001 195K Jun 18  2012 english_setter_125.jpg
# -rwxr-xr-x 1 1001 1001 152K Jun 18  2012 english_setter_126.jpg
# -rwxr-xr-x 1 1001 1001  70K Jun 18  2012 english_setter_127.jpg
# -rwxr-xr-x 1 1001 1001  69K Jun 18  2012 english_setter_128.jpg
# -rwxr-xr-x 1 1001 1001 132K Jun 18  2012 english_setter_129.jpg
# -rwxr-xr-x 1 1001 1001 134K Jun 18  2012 english_setter_12.jpg
# -rwxr-xr-x 1 1001 1001 155K Jun 18  2012 english_setter_130.jpg
# -rwxr-xr-x 1 1001 1001 130K Jun 18  2012 english_setter_131.jpg
# -rwxr-xr-x 1 1001 1001 177K Jun 18  2012 english_setter_132.jpg
# -rwxr-xr-x 1 1001 1001 116K Jun 18  2012 english_setter_133.jpg
# -rwxr-xr-x 1 1001 1001 122K Jun 18  2012 english_setter_134.jpg
# -rwxr-xr-x 1 1001 1001  97K Jun 18  2012 english_setter_135.jpg
# -rwxr-xr-x 1 1001 1001 152K Jun 18  2012 english_setter_136.jpg
# -rwxr-xr-x 1 1001 1001 167K Jun 18  2012 english_setter_137.jpg
# -rwxr-xr-x 1 1001 1001  99K Jun 18  2012 english_setter_138.jpg
# -rwxr-xr-x 1 1001 1001 144K Jun 18  2012 english_setter_139.jpg
# -rwxr-xr-x 1 1001 1001  69K Jun 18  2012 english_setter_13.jpg
# -rwxr-xr-x 1 1001 1001 168K Jun 18  2012 english_setter_140.jpg
# -rwxr-xr-x 1 1001 1001 178K Jun 18  2012 english_setter_141.jpg
# -rwxr-xr-x 1 1001 1001 125K Jun 18  2012 english_setter_142.jpg
# -rwxr-xr-x 1 1001 1001 126K Jun 18  2012 english_setter_143.jpg
# -rwxr-xr-x 1 1001 1001 127K Jun 18  2012 english_setter_144.jpg
# -rwxr-xr-x 1 1001 1001 157K Jun 18  2012 english_setter_145.jpg
# -rwxr-xr-x 1 1001 1001 153K Jun 18  2012 english_setter_146.jpg
# -rwxr-xr-x 1 1001 1001 115K Jun 18  2012 english_setter_147.jpg
# -rwxr-xr-x 1 1001 1001 141K Jun 18  2012 english_setter_148.jpg
# -rwxr-xr-x 1 1001 1001 149K Jun 18  2012 english_setter_149.jpg
# -rwxr-xr-x 1 1001 1001 221K Jun 18  2012 english_setter_14.jpg
# -rwxr-xr-x 1 1001 1001  89K Jun 18  2012 english_setter_150.jpg
# -rwxr-xr-x 1 1001 1001  94K Jun 18  2012 english_setter_151.jpg
# -rwxr-xr-x 1 1001 1001 167K Jun 18  2012 english_setter_152.jpg
# -rwxr-xr-x 1 1001 1001 161K Jun 18  2012 english_setter_153.jpg
# -rwxr-xr-x 1 1001 1001 105K Jun 18  2012 english_setter_154.jpg
# -rwxr-xr-x 1 1001 1001 145K Jun 18  2012 english_setter_155.jpg
# -rwxr-xr-x 1 1001 1001  67K Jun 18  2012 english_setter_156.jpg
# -rwxr-xr-x 1 1001 1001 102K Jun 18  2012 english_setter_157.jpg
# -rwxr-xr-x 1 1001 1001  84K Jun 18  2012 english_setter_158.jpg
# -rwxr-xr-x 1 1001 1001 102K Jun 18  2012 english_setter_159.jpg
# -rwxr-xr-x 1 1001 1001 206K Jun 18  2012 english_setter_15.jpg
# -rwxr-xr-x 1 1001 1001 100K Jun 18  2012 english_setter_160.jpg
# -rwxr-xr-x 1 1001 1001 133K Jun 18  2012 english_setter_161.jpg
# -rwxr-xr-x 1 1001 1001 121K Jun 18  2012 english_setter_162.jpg
# -rwxr-xr-x 1 1001 1001 111K Jun 18  2012 english_setter_163.jpg
# -rwxr-xr-x 1 1001 1001  89K Jun 18  2012 english_setter_164.jpg
# -rwxr-xr-x 1 1001 1001 103K Jun 18  2012 english_setter_165.jpg
# -rwxr-xr-x 1 1001 1001 132K Jun 18  2012 english_setter_166.jpg
# -rwxr-xr-x 1 1001 1001 119K Jun 18  2012 english_setter_167.jpg
# -rwxr-xr-x 1 1001 1001 122K Jun 18  2012 english_setter_168.jpg
# -rwxr-xr-x 1 1001 1001 121K Jun 18  2012 english_setter_169.jpg
# -rwxr-xr-x 1 1001 1001 107K Jun 18  2012 english_setter_16.jpg
# -rwxr-xr-x 1 1001 1001 119K Jun 18  2012 english_setter_170.jpg
# -rwxr-xr-x 1 1001 1001  95K Jun 18  2012 english_setter_171.jpg
# -rwxr-xr-x 1 1001 1001 109K Jun 18  2012 english_setter_172.jpg
# -rwxr-xr-x 1 1001 1001  70K Jun 18  2012 english_setter_173.jpg
# -rwxr-xr-x 1 1001 1001 120K Jun 18  2012 english_setter_174.jpg
# -rwxr-xr-x 1 1001 1001  67K Jun 18  2012 english_setter_175.jpg
# -rwxr-xr-x 1 1001 1001 101K Jun 18  2012 english_setter_176.jpg
# -rwxr-xr-x 1 1001 1001 116K Jun 18  2012 english_setter_177.jpg
# -rwxr-xr-x 1 1001 1001 174K Jun 18  2012 english_setter_178.jpg
# -rwxr-xr-x 1 1001 1001  66K Jun 18  2012 english_setter_179.jpg
# -rwxr-xr-x 1 1001 1001 191K Jun 18  2012 english_setter_17.jpg
# -rwxr-xr-x 1 1001 1001 169K Jun 18  2012 english_setter_180.jpg
# -rwxr-xr-x 1 1001 1001 157K Jun 18  2012 english_setter_181.jpg
# -rwxr-xr-x 1 1001 1001 172K Jun 18  2012 english_setter_182.jpg
# -rwxr-xr-x 1 1001 1001 134K Jun 18  2012 english_setter_183.jpg
# -rwxr-xr-x 1 1001 1001  96K Jun 18  2012 english_setter_184.jpg
# -rwxr-xr-x 1 1001 1001 151K Jun 18  2012 english_setter_185.jpg
# -rwxr-xr-x 1 1001 1001 184K Jun 18  2012 english_setter_186.jpg
# -rwxr-xr-x 1 1001 1001 151K Jun 18  2012 english_setter_187.jpg
# -rwxr-xr-x 1 1001 1001 177K Jun 18  2012 english_setter_188.jpg
# -rwxr-xr-x 1 1001 1001 123K Jun 18  2012 english_setter_189.jpg
# -rwxr-xr-x 1 1001 1001  95K Jun 18  2012 english_setter_18.jpg
# -rwxr-xr-x 1 1001 1001 136K Jun 18  2012 english_setter_190.jpg
# -rwxr-xr-x 1 1001 1001 223K Jun 18  2012 english_setter_191.jpg
# -rwxr-xr-x 1 1001 1001  91K Jun 18  2012 english_setter_192.jpg
# -rwxr-xr-x 1 1001 1001 202K Jun 18  2012 english_setter_193.jpg
# -rwxr-xr-x 1 1001 1001 107K Jun 18  2012 english_setter_194.jpg
# -rwxr-xr-x 1 1001 1001 209K Jun 18  2012 english_setter_195.jpg
# -rwxr-xr-x 1 1001 1001 121K Jun 18  2012 english_setter_196.jpg
# -rwxr-xr-x 1 1001 1001 121K Jun 18  2012 english_setter_197.jpg
# -rwxr-xr-x 1 1001 1001  98K Jun 18  2012 english_setter_198.jpg
# -rwxr-xr-x 1 1001 1001 148K Jun 18  2012 english_setter_199.jpg
# -rwxr-xr-x 1 1001 1001  95K Jun 18  2012 english_setter_19.jpg
# -rwxr-xr-x 1 1001 1001  47K Jun 18  2012 english_setter_1.jpg
# -rwxr-xr-x 1 1001 1001 117K Jun 18  2012 english_setter_200.jpg
# -rwxr-xr-x 1 1001 1001 152K Jun 18  2012 english_setter_20.jpg
# -rwxr-xr-x 1 1001 1001 216K Jun 18  2012 english_setter_21.jpg
# -rwxr-xr-x 1 1001 1001 256K Jun 18  2012 english_setter_22.jpg
# -rwxr-xr-x 1 1001 1001 119K Jun 18  2012 english_setter_23.jpg
# -rwxr-xr-x 1 1001 1001 158K Jun 18  2012 english_setter_24.jpg
# -rwxr-xr-x 1 1001 1001  87K Jun 18  2012 english_setter_25.jpg
# -rwxr-xr-x 1 1001 1001 113K Jun 18  2012 english_setter_26.jpg
# -rwxr-xr-x 1 1001 1001 118K Jun 18  2012 english_setter_27.jpg
# -rwxr-xr-x 1 1001 1001  77K Jun 18  2012 english_setter_28.jpg
# -rwxr-xr-x 1 1001 1001 121K Jun 18  2012 english_setter_29.jpg
# -rwxr-xr-x 1 1001 1001  40K Jun 18  2012 english_setter_2.jpg
# -rwxr-xr-x 1 1001 1001 135K Jun 18  2012 english_setter_30.jpg
# -rwxr-xr-x 1 1001 1001 123K Jun 18  2012 english_setter_31.jpg
# -rwxr-xr-x 1 1001 1001  99K Jun 18  2012 english_setter_32.jpg
# -rwxr-xr-x 1 1001 1001 117K Jun 18  2012 english_setter_33.jpg
# -rwxr-xr-x 1 1001 1001 199K Jun 18  2012 english_setter_34.jpg
# -rwxr-xr-x 1 1001 1001 122K Jun 18  2012 english_setter_35.jpg
# -rwxr-xr-x 1 1001 1001 142K Jun 18  2012 english_setter_36.jpg
# -rwxr-xr-x 1 1001 1001 117K Jun 18  2012 english_setter_37.jpg
# -rwxr-xr-x 1 1001 1001 151K Jun 18  2012 english_setter_38.jpg
# -rwxr-xr-x 1 1001 1001 166K Jun 18  2012 english_setter_39.jpg
# -rwxr-xr-x 1 1001 1001  45K Jun 18  2012 english_setter_3.jpg
# -rwxr-xr-x 1 1001 1001 159K Jun 18  2012 english_setter_40.jpg
# -rwxr-xr-x 1 1001 1001 166K Jun 18  2012 english_setter_41.jpg
# -rwxr-xr-x 1 1001 1001  88K Jun 18  2012 english_setter_42.jpg
# -rwxr-xr-x 1 1001 1001  99K Jun 18  2012 english_setter_43.jpg
# -rwxr-xr-x 1 1001 1001 110K Jun 18  2012 english_setter_44.jpg
# -rwxr-xr-x 1 1001 1001 119K Jun 18  2012 english_setter_45.jpg
# -rwxr-xr-x 1 1001 1001 135K Jun 18  2012 english_setter_46.jpg
# -rwxr-xr-x 1 1001 1001 231K Jun 18  2012 english_setter_47.jpg
# -rwxr-xr-x 1 1001 1001 231K Jun 18  2012 english_setter_48.jpg
# -rwxr-xr-x 1 1001 1001  92K Jun 18  2012 english_setter_49.jpg
# -rwxr-xr-x 1 1001 1001 134K Jun 18  2012 english_setter_4.jpg
# -rwxr-xr-x 1 1001 1001 186K Jun 18  2012 english_setter_50.jpg
# -rwxr-xr-x 1 1001 1001  86K Jun 18  2012 english_setter_51.jpg
# -rwxr-xr-x 1 1001 1001 173K Jun 18  2012 english_setter_52.jpg
# -rwxr-xr-x 1 1001 1001 161K Jun 18  2012 english_setter_53.jpg
# -rwxr-xr-x 1 1001 1001 129K Jun 18  2012 english_setter_54.jpg
# -rwxr-xr-x 1 1001 1001  89K Jun 18  2012 english_setter_55.jpg
# -rwxr-xr-x 1 1001 1001 111K Jun 18  2012 english_setter_56.jpg
# -rwxr-xr-x 1 1001 1001 171K Jun 18  2012 english_setter_57.jpg
# -rwxr-xr-x 1 1001 1001 237K Jun 18  2012 english_setter_58.jpg
# -rwxr-xr-x 1 1001 1001 150K Jun 18  2012 english_setter_59.jpg
# -rwxr-xr-x 1 1001 1001  26K Jun 18  2012 english_setter_5.jpg
# -rwxr-xr-x 1 1001 1001 160K Jun 18  2012 english_setter_60.jpg
# -rwxr-xr-x 1 1001 1001 249K Jun 18  2012 english_setter_61.jpg
# -rwxr-xr-x 1 1001 1001 241K Jun 18  2012 english_setter_62.jpg
# -rwxr-xr-x 1 1001 1001 151K Jun 18  2012 english_setter_63.jpg
# -rwxr-xr-x 1 1001 1001 200K Jun 18  2012 english_setter_64.jpg
# -rwxr-xr-x 1 1001 1001 176K Jun 18  2012 english_setter_65.jpg
# -rwxr-xr-x 1 1001 1001  69K Jun 18  2012 english_setter_66.jpg
# -rwxr-xr-x 1 1001 1001 120K Jun 18  2012 english_setter_67.jpg
# -rwxr-xr-x 1 1001 1001 174K Jun 18  2012 english_setter_68.jpg
# -rwxr-xr-x 1 1001 1001 110K Jun 18  2012 english_setter_69.jpg
# -rwxr-xr-x 1 1001 1001  26K Jun 18  2012 english_setter_6.jpg
# -rwxr-xr-x 1 1001 1001 174K Jun 18  2012 english_setter_70.jpg
# -rwxr-xr-x 1 1001 1001  93K Jun 18  2012 english_setter_71.jpg
# -rwxr-xr-x 1 1001 1001  60K Jun 18  2012 english_setter_72.jpg
# -rwxr-xr-x 1 1001 1001 132K Jun 18  2012 english_setter_73.jpg
# -rwxr-xr-x 1 1001 1001 173K Jun 18  2012 english_setter_74.jpg
# -rwxr-xr-x 1 1001 1001 148K Jun 18  2012 english_setter_75.jpg
# -rwxr-xr-x 1 1001 1001 108K Jun 18  2012 english_setter_76.jpg
# -rwxr-xr-x 1 1001 1001 120K Jun 18  2012 english_setter_77.jpg
# -rwxr-xr-x 1 1001 1001 191K Jun 18  2012 english_setter_78.jpg
# -rwxr-xr-x 1 1001 1001  97K Jun 18  2012 english_setter_79.jpg
# -rwxr-xr-x 1 1001 1001 119K Jun 18  2012 english_setter_7.jpg
# -rwxr-xr-x 1 1001 1001 114K Jun 18  2012 english_setter_80.jpg
# -rwxr-xr-x 1 1001 1001 199K Jun 18  2012 english_setter_81.jpg
# -rwxr-xr-x 1 1001 1001 175K Jun 18  2012 english_setter_82.jpg
# -rwxr-xr-x 1 1001 1001 110K Jun 18  2012 english_setter_83.jpg
# -rwxr-xr-x 1 1001 1001 143K Jun 18  2012 english_setter_84.jpg
# -rwxr-xr-x 1 1001 1001 218K Jun 18  2012 english_setter_85.jpg
# -rwxr-xr-x 1 1001 1001 163K Jun 18  2012 english_setter_86.jpg
# -rwxr-xr-x 1 1001 1001 138K Jun 18  2012 english_setter_87.jpg
# -rwxr-xr-x 1 1001 1001  90K Jun 18  2012 english_setter_88.jpg
# -rwxr-xr-x 1 1001 1001 173K Jun 18  2012 english_setter_89.jpg
# -rwxr-xr-x 1 1001 1001  83K Jun 18  2012 english_setter_8.jpg
# -rwxr-xr-x 1 1001 1001  84K Jun 18  2012 english_setter_90.jpg
# -rwxr-xr-x 1 1001 1001 152K Jun 18  2012 english_setter_91.jpg
# -rwxr-xr-x 1 1001 1001  91K Jun 18  2012 english_setter_92.jpg
# -rwxr-xr-x 1 1001 1001 211K Jun 18  2012 english_setter_93.jpg
# -rwxr-xr-x 1 1001 1001  82K Jun 18  2012 english_setter_94.jpg
# -rwxr-xr-x 1 1001 1001 118K Jun 18  2012 english_setter_95.jpg
# -rwxr-xr-x 1 1001 1001  57K Jun 18  2012 english_setter_96.jpg
# -rwxr-xr-x 1 1001 1001 141K Jun 18  2012 english_setter_97.jpg
# -rwxr-xr-x 1 1001 1001 117K Jun 18  2012 english_setter_98.jpg
# -rwxr-xr-x 1 1001 1001 101K Jun 18  2012 english_setter_99.jpg
# -rwxr-xr-x 1 1001 1001  50K Jun 18  2012 english_setter_9.jpg
# -rwxr-xr-x 1 1001 1001 172K Jun 18  2012 german_shorthaired_100.jpg
# -rwxr-xr-x 1 1001 1001 109K Jun 18  2012 german_shorthaired_101.jpg
# -rwxr-xr-x 1 1001 1001 151K Jun 18  2012 german_shorthaired_102.jpg
# -rwxr-xr-x 1 1001 1001 129K Jun 18  2012 german_shorthaired_103.jpg
# -rwxr-xr-x 1 1001 1001 203K Jun 18  2012 german_shorthaired_104.jpg
# -rwxr-xr-x 1 1001 1001  97K Jun 18  2012 german_shorthaired_105.jpg
# -rwxr-xr-x 1 1001 1001  94K Jun 18  2012 german_shorthaired_106.jpg
# -rwxr-xr-x 1 1001 1001 111K Jun 18  2012 german_shorthaired_107.jpg
# -rwxr-xr-x 1 1001 1001 148K Jun 18  2012 german_shorthaired_108.jpg
# -rwxr-xr-x 1 1001 1001 182K Jun 18  2012 german_shorthaired_109.jpg
# -rwxr-xr-x 1 1001 1001 149K Jun 18  2012 german_shorthaired_10.jpg
# -rwxr-xr-x 1 1001 1001 174K Jun 18  2012 german_shorthaired_110.jpg
# -rwxr-xr-x 1 1001 1001 144K Jun 18  2012 german_shorthaired_111.jpg
# -rwxr-xr-x 1 1001 1001 102K Jun 18  2012 german_shorthaired_112.jpg
# -rwxr-xr-x 1 1001 1001  84K Jun 18  2012 german_shorthaired_113.jpg
# -rwxr-xr-x 1 1001 1001  98K Jun 18  2012 german_shorthaired_114.jpg
# -rwxr-xr-x 1 1001 1001 128K Jun 18  2012 german_shorthaired_115.jpg
# -rwxr-xr-x 1 1001 1001 174K Jun 18  2012 german_shorthaired_116.jpg
# -rwxr-xr-x 1 1001 1001 112K Jun 18  2012 german_shorthaired_117.jpg
# -rwxr-xr-x 1 1001 1001 130K Jun 18  2012 german_shorthaired_118.jpg
# -rwxr-xr-x 1 1001 1001 346K Jun 18  2012 german_shorthaired_119.jpg
# -rwxr-xr-x 1 1001 1001 150K Jun 18  2012 german_shorthaired_11.jpg
# -rwxr-xr-x 1 1001 1001 122K Jun 18  2012 german_shorthaired_120.jpg
# -rwxr-xr-x 1 1001 1001 173K Jun 18  2012 german_shorthaired_121.jpg
# -rwxr-xr-x 1 1001 1001 132K Jun 18  2012 german_shorthaired_122.jpg
# -rwxr-xr-x 1 1001 1001 154K Jun 18  2012 german_shorthaired_123.jpg
# -rwxr-xr-x 1 1001 1001 126K Jun 18  2012 german_shorthaired_124.jpg
# -rwxr-xr-x 1 1001 1001 169K Jun 18  2012 german_shorthaired_125.jpg
# -rwxr-xr-x 1 1001 1001  61K Jun 18  2012 german_shorthaired_126.jpg
# -rwxr-xr-x 1 1001 1001  41K Jun 18  2012 german_shorthaired_127.jpg
# -rwxr-xr-x 1 1001 1001 188K Jun 18  2012 german_shorthaired_128.jpg
# -rwxr-xr-x 1 1001 1001 195K Jun 18  2012 german_shorthaired_129.jpg
# -rwxr-xr-x 1 1001 1001 124K Jun 18  2012 german_shorthaired_12.jpg
# -rwxr-xr-x 1 1001 1001  75K Jun 18  2012 german_shorthaired_130.jpg
# -rwxr-xr-x 1 1001 1001 186K Jun 18  2012 german_shorthaired_131.jpg
# -rwxr-xr-x 1 1001 1001  78K Jun 18  2012 german_shorthaired_132.jpg
# -rwxr-xr-x 1 1001 1001  86K Jun 18  2012 german_shorthaired_133.jpg
# -rwxr-xr-x 1 1001 1001 119K Jun 18  2012 german_shorthaired_134.jpg
# -rwxr-xr-x 1 1001 1001  81K Jun 18  2012 german_shorthaired_135.jpg
# -rwxr-xr-x 1 1001 1001  87K Jun 18  2012 german_shorthaired_136.jpg
# -rwxr-xr-x 1 1001 1001 185K Jun 18  2012 german_shorthaired_137.jpg
# -rwxr-xr-x 1 1001 1001 123K Jun 18  2012 german_shorthaired_138.jpg
# -rwxr-xr-x 1 1001 1001  82K Jun 18  2012 german_shorthaired_139.jpg
# -rwxr-xr-x 1 1001 1001 126K Jun 18  2012 german_shorthaired_13.jpg
# -rwxr-xr-x 1 1001 1001 130K Jun 18  2012 german_shorthaired_140.jpg
# -rwxr-xr-x 1 1001 1001  62K Jun 18  2012 german_shorthaired_141.jpg
# -rwxr-xr-x 1 1001 1001 150K Jun 18  2012 german_shorthaired_142.jpg
# -rwxr-xr-x 1 1001 1001  71K Jun 18  2012 german_shorthaired_143.jpg
# -rwxr-xr-x 1 1001 1001  73K Jun 18  2012 german_shorthaired_144.jpg
# -rwxr-xr-x 1 1001 1001 146K Jun 18  2012 german_shorthaired_145.jpg
# -rwxr-xr-x 1 1001 1001  44K Jun 18  2012 german_shorthaired_146.jpg
# -rwxr-xr-x 1 1001 1001  85K Jun 18  2012 german_shorthaired_147.jpg
# -rwxr-xr-x 1 1001 1001  99K Jun 18  2012 german_shorthaired_148.jpg
# -rwxr-xr-x 1 1001 1001 124K Jun 18  2012 german_shorthaired_149.jpg
# -rwxr-xr-x 1 1001 1001 150K Jun 18  2012 german_shorthaired_14.jpg
# -rwxr-xr-x 1 1001 1001 121K Jun 18  2012 german_shorthaired_150.jpg
# -rwxr-xr-x 1 1001 1001 130K Jun 18  2012 german_shorthaired_151.jpg
# -rwxr-xr-x 1 1001 1001 160K Jun 18  2012 german_shorthaired_152.jpg
# -rwxr-xr-x 1 1001 1001 218K Jun 18  2012 german_shorthaired_153.jpg
# -rwxr-xr-x 1 1001 1001  98K Jun 18  2012 german_shorthaired_154.jpg
# -rwxr-xr-x 1 1001 1001 161K Jun 18  2012 german_shorthaired_155.jpg
# -rwxr-xr-x 1 1001 1001 121K Jun 18  2012 german_shorthaired_156.jpg
# -rwxr-xr-x 1 1001 1001  86K Jun 18  2012 german_shorthaired_157.jpg
# -rwxr-xr-x 1 1001 1001 172K Jun 18  2012 german_shorthaired_158.jpg
# -rwxr-xr-x 1 1001 1001 162K Jun 18  2012 german_shorthaired_159.jpg
# -rwxr-xr-x 1 1001 1001  87K Jun 18  2012 german_shorthaired_15.jpg
# -rwxr-xr-x 1 1001 1001 158K Jun 18  2012 german_shorthaired_160.jpg
# -rwxr-xr-x 1 1001 1001 107K Jun 18  2012 german_shorthaired_161.jpg
# -rwxr-xr-x 1 1001 1001 144K Jun 18  2012 german_shorthaired_162.jpg
# -rwxr-xr-x 1 1001 1001  97K Jun 18  2012 german_shorthaired_163.jpg
# -rwxr-xr-x 1 1001 1001  70K Jun 18  2012 german_shorthaired_164.jpg
# -rwxr-xr-x 1 1001 1001 155K Jun 18  2012 german_shorthaired_165.jpg
# -rwxr-xr-x 1 1001 1001  89K Jun 18  2012 german_shorthaired_166.jpg
# -rwxr-xr-x 1 1001 1001  98K Jun 18  2012 german_shorthaired_167.jpg
# -rwxr-xr-x 1 1001 1001 149K Jun 18  2012 german_shorthaired_168.jpg
# -rwxr-xr-x 1 1001 1001 204K Jun 18  2012 german_shorthaired_169.jpg
# -rwxr-xr-x 1 1001 1001  76K Jun 18  2012 german_shorthaired_16.jpg
# -rwxr-xr-x 1 1001 1001 155K Jun 18  2012 german_shorthaired_170.jpg
# -rwxr-xr-x 1 1001 1001 207K Jun 18  2012 german_shorthaired_171.jpg
# -rwxr-xr-x 1 1001 1001 193K Jun 18  2012 german_shorthaired_172.jpg
# -rwxr-xr-x 1 1001 1001 120K Jun 18  2012 german_shorthaired_173.jpg
# -rwxr-xr-x 1 1001 1001 112K Jun 18  2012 german_shorthaired_174.jpg
# -rwxr-xr-x 1 1001 1001 147K Jun 18  2012 german_shorthaired_175.jpg
# -rwxr-xr-x 1 1001 1001  97K Jun 18  2012 german_shorthaired_176.jpg
# -rwxr-xr-x 1 1001 1001 129K Jun 18  2012 german_shorthaired_177.jpg
# -rwxr-xr-x 1 1001 1001 146K Jun 18  2012 german_shorthaired_178.jpg
# -rwxr-xr-x 1 1001 1001 168K Jun 18  2012 german_shorthaired_179.jpg
# -rwxr-xr-x 1 1001 1001  85K Jun 18  2012 german_shorthaired_17.jpg
# -rwxr-xr-x 1 1001 1001 232K Jun 18  2012 german_shorthaired_180.jpg
# -rwxr-xr-x 1 1001 1001 139K Jun 18  2012 german_shorthaired_181.jpg
# -rwxr-xr-x 1 1001 1001 182K Jun 18  2012 german_shorthaired_182.jpg
# -rwxr-xr-x 1 1001 1001  50K Jun 18  2012 german_shorthaired_183.jpg
# -rwxr-xr-x 1 1001 1001 161K Jun 18  2012 german_shorthaired_184.jpg
# -rwxr-xr-x 1 1001 1001  90K Jun 18  2012 german_shorthaired_185.jpg
# -rwxr-xr-x 1 1001 1001 113K Jun 18  2012 german_shorthaired_186.jpg
# -rwxr-xr-x 1 1001 1001 125K Jun 18  2012 german_shorthaired_187.jpg
# -rwxr-xr-x 1 1001 1001 146K Jun 18  2012 german_shorthaired_188.jpg
# -rwxr-xr-x 1 1001 1001 185K Jun 18  2012 german_shorthaired_189.jpg
# -rwxr-xr-x 1 1001 1001 183K Jun 18  2012 german_shorthaired_18.jpg
# -rwxr-xr-x 1 1001 1001 176K Jun 18  2012 german_shorthaired_190.jpg
# -rwxr-xr-x 1 1001 1001 116K Jun 18  2012 german_shorthaired_191.jpg
# -rwxr-xr-x 1 1001 1001  99K Jun 18  2012 german_shorthaired_192.jpg
# -rwxr-xr-x 1 1001 1001 101K Jun 18  2012 german_shorthaired_193.jpg
# -rwxr-xr-x 1 1001 1001  75K Jun 18  2012 german_shorthaired_194.jpg
# -rwxr-xr-x 1 1001 1001 104K Jun 18  2012 german_shorthaired_195.jpg
# -rwxr-xr-x 1 1001 1001 100K Jun 18  2012 german_shorthaired_196.jpg
# -rwxr-xr-x 1 1001 1001 133K Jun 18  2012 german_shorthaired_197.jpg
# -rwxr-xr-x 1 1001 1001  88K Jun 18  2012 german_shorthaired_198.jpg
# -rwxr-xr-x 1 1001 1001 100K Jun 18  2012 german_shorthaired_199.jpg
# -rwxr-xr-x 1 1001 1001 168K Jun 18  2012 german_shorthaired_19.jpg
# -rwxr-xr-x 1 1001 1001 155K Jun 18  2012 german_shorthaired_1.jpg
# -rwxr-xr-x 1 1001 1001 102K Jun 18  2012 german_shorthaired_200.jpg
# -rwxr-xr-x 1 1001 1001 232K Jun 18  2012 german_shorthaired_20.jpg
# -rwxr-xr-x 1 1001 1001 111K Jun 18  2012 german_shorthaired_21.jpg
# -rwxr-xr-x 1 1001 1001 139K Jun 18  2012 german_shorthaired_22.jpg
# -rwxr-xr-x 1 1001 1001 133K Jun 18  2012 german_shorthaired_23.jpg
# -rwxr-xr-x 1 1001 1001 237K Jun 18  2012 german_shorthaired_24.jpg
# -rwxr-xr-x 1 1001 1001 145K Jun 18  2012 german_shorthaired_25.jpg
# -rwxr-xr-x 1 1001 1001 155K Jun 18  2012 german_shorthaired_26.jpg
# -rwxr-xr-x 1 1001 1001  95K Jun 18  2012 german_shorthaired_27.jpg
# -rwxr-xr-x 1 1001 1001 132K Jun 18  2012 german_shorthaired_28.jpg
# -rwxr-xr-x 1 1001 1001 200K Jun 18  2012 german_shorthaired_29.jpg
# -rwxr-xr-x 1 1001 1001 170K Jun 18  2012 german_shorthaired_2.jpg
# -rwxr-xr-x 1 1001 1001 123K Jun 18  2012 german_shorthaired_30.jpg
# -rwxr-xr-x 1 1001 1001 192K Jun 18  2012 german_shorthaired_31.jpg
# -rwxr-xr-x 1 1001 1001 134K Jun 18  2012 german_shorthaired_32.jpg
# -rwxr-xr-x 1 1001 1001 113K Jun 18  2012 german_shorthaired_33.jpg
# -rwxr-xr-x 1 1001 1001  92K Jun 18  2012 german_shorthaired_34.jpg
# -rwxr-xr-x 1 1001 1001 135K Jun 18  2012 german_shorthaired_35.jpg
# -rwxr-xr-x 1 1001 1001 118K Jun 18  2012 german_shorthaired_36.jpg
# -rwxr-xr-x 1 1001 1001 116K Jun 18  2012 german_shorthaired_37.jpg
# -rwxr-xr-x 1 1001 1001 110K Jun 18  2012 german_shorthaired_38.jpg
# -rwxr-xr-x 1 1001 1001 227K Jun 18  2012 german_shorthaired_39.jpg
# -rwxr-xr-x 1 1001 1001 121K Jun 18  2012 german_shorthaired_3.jpg
# -rwxr-xr-x 1 1001 1001 161K Jun 18  2012 german_shorthaired_40.jpg
# -rwxr-xr-x 1 1001 1001  95K Jun 18  2012 german_shorthaired_41.jpg
# -rwxr-xr-x 1 1001 1001  75K Jun 18  2012 german_shorthaired_42.jpg
# -rwxr-xr-x 1 1001 1001 104K Jun 18  2012 german_shorthaired_43.jpg
# -rwxr-xr-x 1 1001 1001  99K Jun 18  2012 german_shorthaired_44.jpg
# -rwxr-xr-x 1 1001 1001 176K Jun 18  2012 german_shorthaired_45.jpg
# -rwxr-xr-x 1 1001 1001 198K Jun 18  2012 german_shorthaired_46.jpg
# -rwxr-xr-x 1 1001 1001 281K Jun 18  2012 german_shorthaired_47.jpg
# -rwxr-xr-x 1 1001 1001 160K Jun 18  2012 german_shorthaired_48.jpg
# -rwxr-xr-x 1 1001 1001 106K Jun 18  2012 german_shorthaired_49.jpg
# -rwxr-xr-x 1 1001 1001 191K Jun 18  2012 german_shorthaired_4.jpg
# -rwxr-xr-x 1 1001 1001 200K Jun 18  2012 german_shorthaired_50.jpg
# -rwxr-xr-x 1 1001 1001 152K Jun 18  2012 german_shorthaired_51.jpg
# -rwxr-xr-x 1 1001 1001 199K Jun 18  2012 german_shorthaired_52.jpg
# -rwxr-xr-x 1 1001 1001 151K Jun 18  2012 german_shorthaired_53.jpg
# -rwxr-xr-x 1 1001 1001 162K Jun 18  2012 german_shorthaired_54.jpg
# -rwxr-xr-x 1 1001 1001 183K Jun 18  2012 german_shorthaired_55.jpg
# -rwxr-xr-x 1 1001 1001 159K Jun 18  2012 german_shorthaired_56.jpg
# -rwxr-xr-x 1 1001 1001 218K Jun 18  2012 german_shorthaired_57.jpg
# -rwxr-xr-x 1 1001 1001 201K Jun 18  2012 german_shorthaired_58.jpg
# -rwxr-xr-x 1 1001 1001 166K Jun 18  2012 german_shorthaired_59.jpg
# -rwxr-xr-x 1 1001 1001 147K Jun 18  2012 german_shorthaired_5.jpg
# -rwxr-xr-x 1 1001 1001 117K Jun 18  2012 german_shorthaired_60.jpg
# -rwxr-xr-x 1 1001 1001 168K Jun 18  2012 german_shorthaired_61.jpg
# -rwxr-xr-x 1 1001 1001 124K Jun 18  2012 german_shorthaired_62.jpg
# -rwxr-xr-x 1 1001 1001 172K Jun 18  2012 german_shorthaired_63.jpg
# -rwxr-xr-x 1 1001 1001 128K Jun 18  2012 german_shorthaired_64.jpg
# -rwxr-xr-x 1 1001 1001 121K Jun 18  2012 german_shorthaired_65.jpg
# -rwxr-xr-x 1 1001 1001  90K Jun 18  2012 german_shorthaired_66.jpg
# -rwxr-xr-x 1 1001 1001 202K Jun 18  2012 german_shorthaired_67.jpg
# -rwxr-xr-x 1 1001 1001 167K Jun 18  2012 german_shorthaired_68.jpg
# -rwxr-xr-x 1 1001 1001 134K Jun 18  2012 german_shorthaired_69.jpg
# -rwxr-xr-x 1 1001 1001 209K Jun 18  2012 german_shorthaired_6.jpg
# -rwxr-xr-x 1 1001 1001  83K Jun 18  2012 german_shorthaired_70.jpg
# -rwxr-xr-x 1 1001 1001 129K Jun 18  2012 german_shorthaired_71.jpg
# -rwxr-xr-x 1 1001 1001 124K Jun 18  2012 german_shorthaired_72.jpg
# -rwxr-xr-x 1 1001 1001 249K Jun 18  2012 german_shorthaired_73.jpg
# -rwxr-xr-x 1 1001 1001 181K Jun 18  2012 german_shorthaired_74.jpg
# -rwxr-xr-x 1 1001 1001 124K Jun 18  2012 german_shorthaired_75.jpg
# -rwxr-xr-x 1 1001 1001 141K Jun 18  2012 german_shorthaired_76.jpg
# -rwxr-xr-x 1 1001 1001 126K Jun 18  2012 german_shorthaired_77.jpg
# -rwxr-xr-x 1 1001 1001 155K Jun 18  2012 german_shorthaired_78.jpg
# -rwxr-xr-x 1 1001 1001 100K Jun 18  2012 german_shorthaired_79.jpg
# -rwxr-xr-x 1 1001 1001 174K Jun 18  2012 german_shorthaired_7.jpg
# -rwxr-xr-x 1 1001 1001  88K Jun 18  2012 german_shorthaired_80.jpg
# -rwxr-xr-x 1 1001 1001 104K Jun 18  2012 german_shorthaired_81.jpg
# -rwxr-xr-x 1 1001 1001  74K Jun 18  2012 german_shorthaired_82.jpg
# -rwxr-xr-x 1 1001 1001 120K Jun 18  2012 german_shorthaired_83.jpg
# -rwxr-xr-x 1 1001 1001 165K Jun 18  2012 german_shorthaired_84.jpg
# -rwxr-xr-x 1 1001 1001 219K Jun 18  2012 german_shorthaired_85.jpg
# -rwxr-xr-x 1 1001 1001 150K Jun 18  2012 german_shorthaired_86.jpg
# -rwxr-xr-x 1 1001 1001 140K Jun 18  2012 german_shorthaired_87.jpg
# -rwxr-xr-x 1 1001 1001 206K Jun 18  2012 german_shorthaired_88.jpg
# -rwxr-xr-x 1 1001 1001 139K Jun 18  2012 german_shorthaired_89.jpg
# -rwxr-xr-x 1 1001 1001  84K Jun 18  2012 german_shorthaired_8.jpg
# -rwxr-xr-x 1 1001 1001 191K Jun 18  2012 german_shorthaired_90.jpg
# -rwxr-xr-x 1 1001 1001 196K Jun 18  2012 german_shorthaired_91.jpg
# -rwxr-xr-x 1 1001 1001 122K Jun 18  2012 german_shorthaired_92.jpg
# -rwxr-xr-x 1 1001 1001 154K Jun 18  2012 german_shorthaired_93.jpg
# -rwxr-xr-x 1 1001 1001  95K Jun 18  2012 german_shorthaired_94.jpg
# -rwxr-xr-x 1 1001 1001 149K Jun 18  2012 german_shorthaired_95.jpg
# -rwxr-xr-x 1 1001 1001 169K Jun 18  2012 german_shorthaired_96.jpg
# -rwxr-xr-x 1 1001 1001  72K Jun 18  2012 german_shorthaired_97.jpg
# -rwxr-xr-x 1 1001 1001 109K Jun 18  2012 german_shorthaired_98.jpg
# -rwxr-xr-x 1 1001 1001 186K Jun 18  2012 german_shorthaired_99.jpg
# -rwxr-xr-x 1 1001 1001 237K Jun 18  2012 german_shorthaired_9.jpg
# -rwxr-xr-x 1 1001 1001 179K Jun 18  2012 great_pyrenees_100.jpg
# -rwxr-xr-x 1 1001 1001 157K Jun 18  2012 great_pyrenees_101.jpg
# -rwxr-xr-x 1 1001 1001 171K Jun 18  2012 great_pyrenees_102.jpg
# -rwxr-xr-x 1 1001 1001 169K Jun 18  2012 great_pyrenees_103.jpg
# -rwxr-xr-x 1 1001 1001 117K Jun 18  2012 great_pyrenees_104.jpg
# -rwxr-xr-x 1 1001 1001 180K Jun 18  2012 great_pyrenees_105.jpg
# -rwxr-xr-x 1 1001 1001 216K Jun 18  2012 great_pyrenees_106.jpg
# -rwxr-xr-x 1 1001 1001  82K Jun 18  2012 great_pyrenees_107.jpg
# -rwxr-xr-x 1 1001 1001 245K Jun 18  2012 great_pyrenees_108.jpg
# -rwxr-xr-x 1 1001 1001 237K Jun 18  2012 great_pyrenees_109.jpg
# -rwxr-xr-x 1 1001 1001 115K Jun 18  2012 great_pyrenees_10.jpg
# -rwxr-xr-x 1 1001 1001  68K Jun 18  2012 great_pyrenees_110.jpg
# -rwxr-xr-x 1 1001 1001 107K Jun 18  2012 great_pyrenees_111.jpg
# -rwxr-xr-x 1 1001 1001 138K Jun 18  2012 great_pyrenees_112.jpg
# -rwxr-xr-x 1 1001 1001 112K Jun 18  2012 great_pyrenees_113.jpg
# -rwxr-xr-x 1 1001 1001 184K Jun 18  2012 great_pyrenees_114.jpg
# -rwxr-xr-x 1 1001 1001 141K Jun 18  2012 great_pyrenees_115.jpg
# -rwxr-xr-x 1 1001 1001 135K Jun 18  2012 great_pyrenees_116.jpg
# -rwxr-xr-x 1 1001 1001 169K Jun 18  2012 great_pyrenees_117.jpg
# -rwxr-xr-x 1 1001 1001  82K Jun 18  2012 great_pyrenees_118.jpg
# -rwxr-xr-x 1 1001 1001  97K Jun 18  2012 great_pyrenees_119.jpg
# -rwxr-xr-x 1 1001 1001 108K Jun 18  2012 great_pyrenees_11.jpg
# -rwxr-xr-x 1 1001 1001 158K Jun 18  2012 great_pyrenees_120.jpg
# -rwxr-xr-x 1 1001 1001 175K Jun 18  2012 great_pyrenees_121.jpg
# -rwxr-xr-x 1 1001 1001 100K Jun 18  2012 great_pyrenees_122.jpg
# -rwxr-xr-x 1 1001 1001 147K Jun 18  2012 great_pyrenees_123.jpg
# -rwxr-xr-x 1 1001 1001 110K Jun 18  2012 great_pyrenees_124.jpg
# -rwxr-xr-x 1 1001 1001 114K Jun 18  2012 great_pyrenees_125.jpg
# -rwxr-xr-x 1 1001 1001 168K Jun 18  2012 great_pyrenees_126.jpg
# -rwxr-xr-x 1 1001 1001 206K Jun 18  2012 great_pyrenees_127.jpg
# -rwxr-xr-x 1 1001 1001  63K Jun 18  2012 great_pyrenees_128.jpg
# -rwxr-xr-x 1 1001 1001 167K Jun 18  2012 great_pyrenees_129.jpg
# -rwxr-xr-x 1 1001 1001 109K Jun 18  2012 great_pyrenees_12.jpg
# -rwxr-xr-x 1 1001 1001  85K Jun 18  2012 great_pyrenees_130.jpg
# -rwxr-xr-x 1 1001 1001  71K Jun 18  2012 great_pyrenees_131.jpg
# -rwxr-xr-x 1 1001 1001  73K Jun 18  2012 great_pyrenees_132.jpg
# -rwxr-xr-x 1 1001 1001  66K Jun 18  2012 great_pyrenees_133.jpg
# -rwxr-xr-x 1 1001 1001 128K Jun 18  2012 great_pyrenees_134.jpg
# -rwxr-xr-x 1 1001 1001  38K Jun 18  2012 great_pyrenees_135.jpg
# -rwxr-xr-x 1 1001 1001  46K Jun 18  2012 great_pyrenees_136.jpg
# -rwxr-xr-x 1 1001 1001  35K Jun 18  2012 great_pyrenees_137.jpg
# -rwxr-xr-x 1 1001 1001  15K Jun 18  2012 great_pyrenees_138.jpg
# -rwxr-xr-x 1 1001 1001  59K Jun 18  2012 great_pyrenees_139.jpg
# -rwxr-xr-x 1 1001 1001  72K Jun 18  2012 great_pyrenees_13.jpg
# -rwxr-xr-x 1 1001 1001  59K Jun 18  2012 great_pyrenees_140.jpg
# -rwxr-xr-x 1 1001 1001  34K Jun 18  2012 great_pyrenees_141.jpg
# -rwxr-xr-x 1 1001 1001  41K Jun 18  2012 great_pyrenees_142.jpg
# -rwxr-xr-x 1 1001 1001  40K Jun 18  2012 great_pyrenees_143.jpg
# -rwxr-xr-x 1 1001 1001  58K Jun 18  2012 great_pyrenees_144.jpg
# -rwxr-xr-x 1 1001 1001  39K Jun 18  2012 great_pyrenees_145.jpg
# -rwxr-xr-x 1 1001 1001  35K Jun 18  2012 great_pyrenees_146.jpg
# -rwxr-xr-x 1 1001 1001  36K Jun 18  2012 great_pyrenees_147.jpg
# -rwxr-xr-x 1 1001 1001  63K Jun 18  2012 great_pyrenees_148.jpg
# -rwxr-xr-x 1 1001 1001  80K Jun 18  2012 great_pyrenees_149.jpg
# -rwxr-xr-x 1 1001 1001  81K Jun 18  2012 great_pyrenees_14.jpg
# -rwxr-xr-x 1 1001 1001  31K Jun 18  2012 great_pyrenees_150.jpg
# -rwxr-xr-x 1 1001 1001  69K Jun 18  2012 great_pyrenees_151.jpg
# -rwxr-xr-x 1 1001 1001  57K Jun 18  2012 great_pyrenees_152.jpg
# -rwxr-xr-x 1 1001 1001  66K Jun 18  2012 great_pyrenees_153.jpg
# -rwxr-xr-x 1 1001 1001 131K Jun 18  2012 great_pyrenees_154.jpg
# -rwxr-xr-x 1 1001 1001  32K Jun 18  2012 great_pyrenees_155.jpg
# -rwxr-xr-x 1 1001 1001  65K Jun 18  2012 great_pyrenees_156.jpg
# -rwxr-xr-x 1 1001 1001  73K Jun 18  2012 great_pyrenees_157.jpg
# -rwxr-xr-x 1 1001 1001  26K Jun 18  2012 great_pyrenees_158.jpg
# -rwxr-xr-x 1 1001 1001  53K Jun 18  2012 great_pyrenees_159.jpg
# -rwxr-xr-x 1 1001 1001  87K Jun 18  2012 great_pyrenees_15.jpg
# -rwxr-xr-x 1 1001 1001  56K Jun 18  2012 great_pyrenees_160.jpg
# -rwxr-xr-x 1 1001 1001  64K Jun 18  2012 great_pyrenees_161.jpg
# -rwxr-xr-x 1 1001 1001  36K Jun 18  2012 great_pyrenees_162.jpg
# -rwxr-xr-x 1 1001 1001 200K Jun 18  2012 great_pyrenees_163.jpg
# -rwxr-xr-x 1 1001 1001  54K Jun 18  2012 great_pyrenees_164.jpg
# -rwxr-xr-x 1 1001 1001  44K Jun 18  2012 great_pyrenees_165.jpg
# -rwxr-xr-x 1 1001 1001  41K Jun 18  2012 great_pyrenees_166.jpg
# -rwxr-xr-x 1 1001 1001  30K Jun 18  2012 great_pyrenees_167.jpg
# -rwxr-xr-x 1 1001 1001  34K Jun 18  2012 great_pyrenees_168.jpg
# -rwxr-xr-x 1 1001 1001  20K Jun 18  2012 great_pyrenees_169.jpg
# -rwxr-xr-x 1 1001 1001 106K Jun 18  2012 great_pyrenees_16.jpg
# -rwxr-xr-x 1 1001 1001  38K Jun 18  2012 great_pyrenees_170.jpg
# -rwxr-xr-x 1 1001 1001  50K Jun 18  2012 great_pyrenees_171.jpg
# -rwxr-xr-x 1 1001 1001  83K Jun 18  2012 great_pyrenees_172.jpg
# -rwxr-xr-x 1 1001 1001 210K Jun 18  2012 great_pyrenees_173.jpg
# -rwxr-xr-x 1 1001 1001  37K Jun 18  2012 great_pyrenees_174.jpg
# -rwxr-xr-x 1 1001 1001  59K Jun 18  2012 great_pyrenees_175.jpg
# -rwxr-xr-x 1 1001 1001 152K Jun 18  2012 great_pyrenees_176.jpg
# -rwxr-xr-x 1 1001 1001 100K Jun 18  2012 great_pyrenees_177.jpg
# -rwxr-xr-x 1 1001 1001 133K Jun 18  2012 great_pyrenees_178.jpg
# -rwxr-xr-x 1 1001 1001 169K Jun 18  2012 great_pyrenees_179.jpg
# -rwxr-xr-x 1 1001 1001  92K Jun 18  2012 great_pyrenees_17.jpg
# -rwxr-xr-x 1 1001 1001 173K Jun 18  2012 great_pyrenees_180.jpg
# -rwxr-xr-x 1 1001 1001  65K Jun 18  2012 great_pyrenees_181.jpg
# -rwxr-xr-x 1 1001 1001 139K Jun 18  2012 great_pyrenees_182.jpg
# -rwxr-xr-x 1 1001 1001 111K Jun 18  2012 great_pyrenees_183.jpg
# -rwxr-xr-x 1 1001 1001  75K Jun 18  2012 great_pyrenees_184.jpg
# -rwxr-xr-x 1 1001 1001  58K Jun 18  2012 great_pyrenees_185.jpg
# -rwxr-xr-x 1 1001 1001  85K Jun 18  2012 great_pyrenees_186.jpg
# -rwxr-xr-x 1 1001 1001 146K Jun 18  2012 great_pyrenees_187.jpg
# -rwxr-xr-x 1 1001 1001  97K Jun 18  2012 great_pyrenees_188.jpg
# -rwxr-xr-x 1 1001 1001 145K Jun 18  2012 great_pyrenees_189.jpg
# -rwxr-xr-x 1 1001 1001  90K Jun 18  2012 great_pyrenees_18.jpg
# -rwxr-xr-x 1 1001 1001 121K Jun 18  2012 great_pyrenees_190.jpg
# -rwxr-xr-x 1 1001 1001 143K Jun 18  2012 great_pyrenees_191.jpg
# -rwxr-xr-x 1 1001 1001 131K Jun 18  2012 great_pyrenees_192.jpg
# -rwxr-xr-x 1 1001 1001 139K Jun 18  2012 great_pyrenees_193.jpg
# -rwxr-xr-x 1 1001 1001 104K Jun 18  2012 great_pyrenees_194.jpg
# -rwxr-xr-x 1 1001 1001 111K Jun 18  2012 great_pyrenees_195.jpg
# -rwxr-xr-x 1 1001 1001 206K Jun 18  2012 great_pyrenees_196.jpg
# -rwxr-xr-x 1 1001 1001 115K Jun 18  2012 great_pyrenees_197.jpg
# ...
# -rwxr-xr-x 1 1001 1001 105K Jun 18  2012 wheaten_terrier_62.jpg
# -rwxr-xr-x 1 1001 1001  89K Jun 18  2012 wheaten_terrier_63.jpg
# -rwxr-xr-x 1 1001 1001 187K Jun 18  2012 wheaten_terrier_64.jpg
# -rwxr-xr-x 1 1001 1001 212K Jun 18  2012 wheaten_terrier_65.jpg
# -rwxr-xr-x 1 1001 1001 101K Jun 18  2012 wheaten_terrier_66.jpg
# -rwxr-xr-x 1 1001 1001  88K Jun 18  2012 wheaten_terrier_67.jpg
# -rwxr-xr-x 1 1001 1001 117K Jun 18  2012 wheaten_terrier_68.jpg
# -rwxr-xr-x 1 1001 1001  66K Jun 18  2012 wheaten_terrier_69.jpg
# -rwxr-xr-x 1 1001 1001 126K Jun 18  2012 wheaten_terrier_6.jpg
# -rwxr-xr-x 1 1001 1001 174K Jun 18  2012 wheaten_terrier_70.jpg
# -rwxr-xr-x 1 1001 1001 120K Jun 18  2012 wheaten_terrier_71.jpg
# -rwxr-xr-x 1 1001 1001 194K Jun 18  2012 wheaten_terrier_72.jpg
# -rwxr-xr-x 1 1001 1001 146K Jun 18  2012 wheaten_terrier_73.jpg
# -rwxr-xr-x 1 1001 1001  77K Jun 18  2012 wheaten_terrier_74.jpg
# -rwxr-xr-x 1 1001 1001 133K Jun 18  2012 wheaten_terrier_75.jpg
# -rwxr-xr-x 1 1001 1001  79K Jun 18  2012 wheaten_terrier_76.jpg
# -rwxr-xr-x 1 1001 1001  94K Jun 18  2012 wheaten_terrier_77.jpg
# -rwxr-xr-x 1 1001 1001 203K Jun 18  2012 wheaten_terrier_78.jpg
# -rwxr-xr-x 1 1001 1001 159K Jun 18  2012 wheaten_terrier_79.jpg
# -rwxr-xr-x 1 1001 1001 128K Jun 18  2012 wheaten_terrier_7.jpg
# -rwxr-xr-x 1 1001 1001 127K Jun 18  2012 wheaten_terrier_80.jpg
# -rwxr-xr-x 1 1001 1001 121K Jun 18  2012 wheaten_terrier_81.jpg
# -rwxr-xr-x 1 1001 1001 143K Jun 18  2012 wheaten_terrier_82.jpg
# -rwxr-xr-x 1 1001 1001 149K Jun 18  2012 wheaten_terrier_83.jpg
# -rwxr-xr-x 1 1001 1001 140K Jun 18  2012 wheaten_terrier_84.jpg
# -rwxr-xr-x 1 1001 1001 178K Jun 18  2012 wheaten_terrier_85.jpg
# -rwxr-xr-x 1 1001 1001  92K Jun 18  2012 wheaten_terrier_86.jpg
# -rwxr-xr-x 1 1001 1001 238K Jun 18  2012 wheaten_terrier_87.jpg
# -rwxr-xr-x 1 1001 1001 142K Jun 18  2012 wheaten_terrier_88.jpg
# -rwxr-xr-x 1 1001 1001 125K Jun 18  2012 wheaten_terrier_89.jpg
# -rwxr-xr-x 1 1001 1001 149K Jun 18  2012 wheaten_terrier_8.jpg
# -rwxr-xr-x 1 1001 1001 167K Jun 18  2012 wheaten_terrier_90.jpg
# -rwxr-xr-x 1 1001 1001 163K Jun 18  2012 wheaten_terrier_91.jpg
# -rwxr-xr-x 1 1001 1001 121K Jun 18  2012 wheaten_terrier_92.jpg
# -rwxr-xr-x 1 1001 1001 117K Jun 18  2012 wheaten_terrier_93.jpg
# -rwxr-xr-x 1 1001 1001 110K Jun 18  2012 wheaten_terrier_94.jpg
# -rwxr-xr-x 1 1001 1001  91K Jun 18  2012 wheaten_terrier_95.jpg
# -rwxr-xr-x 1 1001 1001 155K Jun 18  2012 wheaten_terrier_96.jpg
# -rwxr-xr-x 1 1001 1001  83K Jun 18  2012 wheaten_terrier_97.jpg
# -rwxr-xr-x 1 1001 1001  79K Jun 18  2012 wheaten_terrier_98.jpg
# -rwxr-xr-x 1 1001 1001 176K Jun 18  2012 wheaten_terrier_99.jpg
# -rwxr-xr-x 1 1001 1001  80K Jun 18  2012 wheaten_terrier_9.jpg
# -rwxr-xr-x 1 1001 1001  87K Jun 18  2012 yorkshire_terrier_100.jpg
# -rwxr-xr-x 1 1001 1001 151K Jun 18  2012 yorkshire_terrier_101.jpg
# -rwxr-xr-x 1 1001 1001 126K Jun 18  2012 yorkshire_terrier_102.jpg
# -rwxr-xr-x 1 1001 1001 181K Jun 18  2012 yorkshire_terrier_103.jpg
# -rwxr-xr-x 1 1001 1001 110K Jun 18  2012 yorkshire_terrier_104.jpg
# -rwxr-xr-x 1 1001 1001  70K Jun 18  2012 yorkshire_terrier_105.jpg
# -rwxr-xr-x 1 1001 1001 158K Jun 18  2012 yorkshire_terrier_106.jpg
# -rwxr-xr-x 1 1001 1001 103K Jun 18  2012 yorkshire_terrier_107.jpg
# -rwxr-xr-x 1 1001 1001 186K Jun 18  2012 yorkshire_terrier_108.jpg
# -rwxr-xr-x 1 1001 1001 139K Jun 18  2012 yorkshire_terrier_109.jpg
# -rwxr-xr-x 1 1001 1001 103K Jun 18  2012 yorkshire_terrier_10.jpg
# -rwxr-xr-x 1 1001 1001 130K Jun 18  2012 yorkshire_terrier_110.jpg
# -rwxr-xr-x 1 1001 1001  91K Jun 18  2012 yorkshire_terrier_111.jpg
# -rwxr-xr-x 1 1001 1001 117K Jun 18  2012 yorkshire_terrier_112.jpg
# -rwxr-xr-x 1 1001 1001  14K Jun 18  2012 yorkshire_terrier_113.jpg
# -rwxr-xr-x 1 1001 1001  12K Jun 18  2012 yorkshire_terrier_114.jpg
# -rwxr-xr-x 1 1001 1001  12K Jun 18  2012 yorkshire_terrier_115.jpg
# -rwxr-xr-x 1 1001 1001  16K Jun 18  2012 yorkshire_terrier_116.jpg
# -rwxr-xr-x 1 1001 1001  28K Jun 18  2012 yorkshire_terrier_117.jpg
# -rwxr-xr-x 1 1001 1001  12K Jun 18  2012 yorkshire_terrier_118.jpg
# -rwxr-xr-x 1 1001 1001  16K Jun 18  2012 yorkshire_terrier_119.jpg
# -rwxr-xr-x 1 1001 1001  74K Jun 18  2012 yorkshire_terrier_11.jpg
# -rwxr-xr-x 1 1001 1001 6.8K Jun 18  2012 yorkshire_terrier_120.jpg
# -rwxr-xr-x 1 1001 1001  14K Jun 18  2012 yorkshire_terrier_121.jpg
# -rwxr-xr-x 1 1001 1001  13K Jun 18  2012 yorkshire_terrier_122.jpg
# -rwxr-xr-x 1 1001 1001 6.4K Jun 18  2012 yorkshire_terrier_123.jpg
# -rwxr-xr-x 1 1001 1001  11K Jun 18  2012 yorkshire_terrier_124.jpg
# -rwxr-xr-x 1 1001 1001 5.2K Jun 18  2012 yorkshire_terrier_125.jpg
# -rwxr-xr-x 1 1001 1001 9.8K Jun 18  2012 yorkshire_terrier_126.jpg
# -rwxr-xr-x 1 1001 1001  18K Jun 18  2012 yorkshire_terrier_127.jpg
# -rwxr-xr-x 1 1001 1001  13K Jun 18  2012 yorkshire_terrier_128.jpg
# -rwxr-xr-x 1 1001 1001  10K Jun 18  2012 yorkshire_terrier_129.jpg
# -rwxr-xr-x 1 1001 1001 151K Jun 18  2012 yorkshire_terrier_12.jpg
# -rwxr-xr-x 1 1001 1001 6.6K Jun 18  2012 yorkshire_terrier_130.jpg
# -rwxr-xr-x 1 1001 1001 9.6K Jun 18  2012 yorkshire_terrier_131.jpg
# -rwxr-xr-x 1 1001 1001  12K Jun 18  2012 yorkshire_terrier_132.jpg
# -rwxr-xr-x 1 1001 1001  11K Jun 18  2012 yorkshire_terrier_133.jpg
# -rwxr-xr-x 1 1001 1001  11K Jun 18  2012 yorkshire_terrier_134.jpg
# -rwxr-xr-x 1 1001 1001 9.7K Jun 18  2012 yorkshire_terrier_135.jpg
# -rwxr-xr-x 1 1001 1001  11K Jun 18  2012 yorkshire_terrier_136.jpg
# -rwxr-xr-x 1 1001 1001 9.0K Jun 18  2012 yorkshire_terrier_137.jpg
# -rwxr-xr-x 1 1001 1001  12K Jun 18  2012 yorkshire_terrier_138.jpg
# -rwxr-xr-x 1 1001 1001  11K Jun 18  2012 yorkshire_terrier_139.jpg
# -rwxr-xr-x 1 1001 1001 243K Jun 18  2012 yorkshire_terrier_13.jpg
# -rwxr-xr-x 1 1001 1001  11K Jun 18  2012 yorkshire_terrier_140.jpg
# -rwxr-xr-x 1 1001 1001  12K Jun 18  2012 yorkshire_terrier_141.jpg
# -rwxr-xr-x 1 1001 1001 8.9K Jun 18  2012 yorkshire_terrier_142.jpg
# -rwxr-xr-x 1 1001 1001  11K Jun 18  2012 yorkshire_terrier_143.jpg
# -rwxr-xr-x 1 1001 1001 8.5K Jun 18  2012 yorkshire_terrier_144.jpg
# -rwxr-xr-x 1 1001 1001  12K Jun 18  2012 yorkshire_terrier_145.jpg
# -rwxr-xr-x 1 1001 1001 8.2K Jun 18  2012 yorkshire_terrier_146.jpg
# -rwxr-xr-x 1 1001 1001  13K Jun 18  2012 yorkshire_terrier_147.jpg
# -rwxr-xr-x 1 1001 1001 9.5K Jun 18  2012 yorkshire_terrier_148.jpg
# -rwxr-xr-x 1 1001 1001  12K Jun 18  2012 yorkshire_terrier_149.jpg
# -rwxr-xr-x 1 1001 1001 123K Jun 18  2012 yorkshire_terrier_14.jpg
# -rwxr-xr-x 1 1001 1001 8.9K Jun 18  2012 yorkshire_terrier_150.jpg
# -rwxr-xr-x 1 1001 1001 9.7K Jun 18  2012 yorkshire_terrier_151.jpg
# -rwxr-xr-x 1 1001 1001  11K Jun 18  2012 yorkshire_terrier_152.jpg
# -rwxr-xr-x 1 1001 1001  12K Jun 18  2012 yorkshire_terrier_153.jpg
# -rwxr-xr-x 1 1001 1001 9.9K Jun 18  2012 yorkshire_terrier_154.jpg
# -rwxr-xr-x 1 1001 1001  11K Jun 18  2012 yorkshire_terrier_155.jpg
# -rwxr-xr-x 1 1001 1001 9.3K Jun 18  2012 yorkshire_terrier_156.jpg
# -rwxr-xr-x 1 1001 1001  15K Jun 18  2012 yorkshire_terrier_157.jpg
# -rwxr-xr-x 1 1001 1001  13K Jun 18  2012 yorkshire_terrier_158.jpg
# -rwxr-xr-x 1 1001 1001 125K Jun 18  2012 yorkshire_terrier_159.jpg
# -rwxr-xr-x 1 1001 1001 205K Jun 18  2012 yorkshire_terrier_15.jpg
# -rwxr-xr-x 1 1001 1001 130K Jun 18  2012 yorkshire_terrier_160.jpg
# -rwxr-xr-x 1 1001 1001 101K Jun 18  2012 yorkshire_terrier_161.jpg
# -rwxr-xr-x 1 1001 1001 115K Jun 18  2012 yorkshire_terrier_162.jpg
# -rwxr-xr-x 1 1001 1001 133K Jun 18  2012 yorkshire_terrier_163.jpg
# -rwxr-xr-x 1 1001 1001 123K Jun 18  2012 yorkshire_terrier_164.jpg
# -rwxr-xr-x 1 1001 1001  48K Jun 18  2012 yorkshire_terrier_165.jpg
# -rwxr-xr-x 1 1001 1001 128K Jun 18  2012 yorkshire_terrier_166.jpg
# -rwxr-xr-x 1 1001 1001 126K Jun 18  2012 yorkshire_terrier_167.jpg
# -rwxr-xr-x 1 1001 1001 105K Jun 18  2012 yorkshire_terrier_168.jpg
# -rwxr-xr-x 1 1001 1001  98K Jun 18  2012 yorkshire_terrier_169.jpg
# -rwxr-xr-x 1 1001 1001 110K Jun 18  2012 yorkshire_terrier_16.jpg
# -rwxr-xr-x 1 1001 1001  98K Jun 18  2012 yorkshire_terrier_170.jpg
# -rwxr-xr-x 1 1001 1001 133K Jun 18  2012 yorkshire_terrier_171.jpg
# -rwxr-xr-x 1 1001 1001 139K Jun 18  2012 yorkshire_terrier_172.jpg
# -rwxr-xr-x 1 1001 1001 117K Jun 18  2012 yorkshire_terrier_173.jpg
# -rwxr-xr-x 1 1001 1001 119K Jun 18  2012 yorkshire_terrier_174.jpg
# -rwxr-xr-x 1 1001 1001 146K Jun 18  2012 yorkshire_terrier_175.jpg
# -rwxr-xr-x 1 1001 1001 122K Jun 18  2012 yorkshire_terrier_176.jpg
# -rwxr-xr-x 1 1001 1001 147K Jun 18  2012 yorkshire_terrier_177.jpg
# -rwxr-xr-x 1 1001 1001 125K Jun 18  2012 yorkshire_terrier_178.jpg
# -rwxr-xr-x 1 1001 1001 138K Jun 18  2012 yorkshire_terrier_179.jpg
# -rwxr-xr-x 1 1001 1001  82K Jun 18  2012 yorkshire_terrier_17.jpg
# -rwxr-xr-x 1 1001 1001 149K Jun 18  2012 yorkshire_terrier_180.jpg
# -rwxr-xr-x 1 1001 1001 132K Jun 18  2012 yorkshire_terrier_181.jpg
# -rwxr-xr-x 1 1001 1001 145K Jun 18  2012 yorkshire_terrier_182.jpg
# -rwxr-xr-x 1 1001 1001 137K Jun 18  2012 yorkshire_terrier_183.jpg
# -rwxr-xr-x 1 1001 1001 128K Jun 18  2012 yorkshire_terrier_184.jpg
# -rwxr-xr-x 1 1001 1001 161K Jun 18  2012 yorkshire_terrier_185.jpg
# -rwxr-xr-x 1 1001 1001 145K Jun 18  2012 yorkshire_terrier_186.jpg
# -rwxr-xr-x 1 1001 1001 116K Jun 18  2012 yorkshire_terrier_187.jpg
# -rwxr-xr-x 1 1001 1001  96K Jun 18  2012 yorkshire_terrier_188.jpg
# -rwxr-xr-x 1 1001 1001 137K Jun 18  2012 yorkshire_terrier_189.jpg
# -rwxr-xr-x 1 1001 1001 173K Jun 18  2012 yorkshire_terrier_18.jpg
# -rwxr-xr-x 1 1001 1001 118K Jun 18  2012 yorkshire_terrier_190.jpg
# -rwxr-xr-x 1 1001 1001 102K Jun 18  2012 yorkshire_terrier_191.jpg
# -rwxr-xr-x 1 1001 1001 137K Jun 18  2012 yorkshire_terrier_192.jpg
# -rwxr-xr-x 1 1001 1001 140K Jun 18  2012 yorkshire_terrier_193.jpg
# -rwxr-xr-x 1 1001 1001 114K Jun 18  2012 yorkshire_terrier_194.jpg
# -rwxr-xr-x 1 1001 1001  96K Jun 18  2012 yorkshire_terrier_195.jpg
# -rwxr-xr-x 1 1001 1001  75K Jun 18  2012 yorkshire_terrier_196.jpg
# -rwxr-xr-x 1 1001 1001 127K Jun 18  2012 yorkshire_terrier_197.jpg
# -rwxr-xr-x 1 1001 1001 180K Jun 18  2012 yorkshire_terrier_198.jpg
# -rwxr-xr-x 1 1001 1001 210K Jun 18  2012 yorkshire_terrier_199.jpg
# -rwxr-xr-x 1 1001 1001 112K Jun 18  2012 yorkshire_terrier_19.jpg
# -rwxr-xr-x 1 1001 1001 117K Jun 18  2012 yorkshire_terrier_1.jpg
# -rwxr-xr-x 1 1001 1001 120K Jun 18  2012 yorkshire_terrier_200.jpg
# -rwxr-xr-x 1 1001 1001 150K Jun 18  2012 yorkshire_terrier_20.jpg
# -rwxr-xr-x 1 1001 1001 135K Jun 18  2012 yorkshire_terrier_21.jpg
# -rwxr-xr-x 1 1001 1001  56K Jun 18  2012 yorkshire_terrier_22.jpg
# -rwxr-xr-x 1 1001 1001 158K Jun 18  2012 yorkshire_terrier_23.jpg
# -rwxr-xr-x 1 1001 1001 127K Jun 18  2012 yorkshire_terrier_24.jpg
# -rwxr-xr-x 1 1001 1001 158K Jun 18  2012 yorkshire_terrier_25.jpg
# -rwxr-xr-x 1 1001 1001 131K Jun 18  2012 yorkshire_terrier_26.jpg
# -rwxr-xr-x 1 1001 1001  96K Jun 18  2012 yorkshire_terrier_27.jpg
# -rwxr-xr-x 1 1001 1001 126K Jun 18  2012 yorkshire_terrier_28.jpg
# -rwxr-xr-x 1 1001 1001 161K Jun 18  2012 yorkshire_terrier_29.jpg
# -rwxr-xr-x 1 1001 1001 112K Jun 18  2012 yorkshire_terrier_2.jpg
# -rwxr-xr-x 1 1001 1001 108K Jun 18  2012 yorkshire_terrier_30.jpg
# -rwxr-xr-x 1 1001 1001 167K Jun 18  2012 yorkshire_terrier_31.jpg
# -rwxr-xr-x 1 1001 1001 230K Jun 18  2012 yorkshire_terrier_32.jpg
# -rwxr-xr-x 1 1001 1001  95K Jun 18  2012 yorkshire_terrier_33.jpg
# -rwxr-xr-x 1 1001 1001 131K Jun 18  2012 yorkshire_terrier_34.jpg
# -rwxr-xr-x 1 1001 1001 106K Jun 18  2012 yorkshire_terrier_35.jpg
# -rwxr-xr-x 1 1001 1001 142K Jun 18  2012 yorkshire_terrier_36.jpg
# -rwxr-xr-x 1 1001 1001  77K Jun 18  2012 yorkshire_terrier_37.jpg
# -rwxr-xr-x 1 1001 1001 126K Jun 18  2012 yorkshire_terrier_38.jpg
# -rwxr-xr-x 1 1001 1001  95K Jun 18  2012 yorkshire_terrier_39.jpg
# -rwxr-xr-x 1 1001 1001  90K Jun 18  2012 yorkshire_terrier_3.jpg
# -rwxr-xr-x 1 1001 1001  96K Jun 18  2012 yorkshire_terrier_40.jpg
# -rwxr-xr-x 1 1001 1001 101K Jun 18  2012 yorkshire_terrier_41.jpg
# -rwxr-xr-x 1 1001 1001 144K Jun 18  2012 yorkshire_terrier_42.jpg
# -rwxr-xr-x 1 1001 1001 120K Jun 18  2012 yorkshire_terrier_43.jpg
# -rwxr-xr-x 1 1001 1001 127K Jun 18  2012 yorkshire_terrier_44.jpg
# -rwxr-xr-x 1 1001 1001 127K Jun 18  2012 yorkshire_terrier_45.jpg
# -rwxr-xr-x 1 1001 1001 140K Jun 18  2012 yorkshire_terrier_46.jpg
# -rwxr-xr-x 1 1001 1001  96K Jun 18  2012 yorkshire_terrier_47.jpg
# -rwxr-xr-x 1 1001 1001 108K Jun 18  2012 yorkshire_terrier_48.jpg
# -rwxr-xr-x 1 1001 1001 155K Jun 18  2012 yorkshire_terrier_49.jpg
# -rwxr-xr-x 1 1001 1001 153K Jun 18  2012 yorkshire_terrier_4.jpg
# -rwxr-xr-x 1 1001 1001 118K Jun 18  2012 yorkshire_terrier_50.jpg
# -rwxr-xr-x 1 1001 1001 166K Jun 18  2012 yorkshire_terrier_51.jpg
# -rwxr-xr-x 1 1001 1001 159K Jun 18  2012 yorkshire_terrier_52.jpg
# -rwxr-xr-x 1 1001 1001 158K Jun 18  2012 yorkshire_terrier_53.jpg
# -rwxr-xr-x 1 1001 1001 107K Jun 18  2012 yorkshire_terrier_54.jpg
# -rwxr-xr-x 1 1001 1001 101K Jun 18  2012 yorkshire_terrier_55.jpg
# -rwxr-xr-x 1 1001 1001 141K Jun 18  2012 yorkshire_terrier_56.jpg
# -rwxr-xr-x 1 1001 1001 114K Jun 18  2012 yorkshire_terrier_57.jpg
# -rwxr-xr-x 1 1001 1001  97K Jun 18  2012 yorkshire_terrier_58.jpg
# -rwxr-xr-x 1 1001 1001 239K Jun 18  2012 yorkshire_terrier_59.jpg
# -rwxr-xr-x 1 1001 1001 262K Jun 18  2012 yorkshire_terrier_5.jpg
# -rwxr-xr-x 1 1001 1001  84K Jun 18  2012 yorkshire_terrier_60.jpg
# -rwxr-xr-x 1 1001 1001 112K Jun 18  2012 yorkshire_terrier_61.jpg
# -rwxr-xr-x 1 1001 1001 135K Jun 18  2012 yorkshire_terrier_62.jpg
# -rwxr-xr-x 1 1001 1001  93K Jun 18  2012 yorkshire_terrier_63.jpg
# -rwxr-xr-x 1 1001 1001 103K Jun 18  2012 yorkshire_terrier_64.jpg
# -rwxr-xr-x 1 1001 1001 175K Jun 18  2012 yorkshire_terrier_65.jpg
# -rwxr-xr-x 1 1001 1001 170K Jun 18  2012 yorkshire_terrier_66.jpg
# -rwxr-xr-x 1 1001 1001 109K Jun 18  2012 yorkshire_terrier_67.jpg
# -rwxr-xr-x 1 1001 1001 131K Jun 18  2012 yorkshire_terrier_68.jpg
# -rwxr-xr-x 1 1001 1001 113K Jun 18  2012 yorkshire_terrier_69.jpg
# -rwxr-xr-x 1 1001 1001 162K Jun 18  2012 yorkshire_terrier_6.jpg
# -rwxr-xr-x 1 1001 1001 151K Jun 18  2012 yorkshire_terrier_70.jpg
# -rwxr-xr-x 1 1001 1001 132K Jun 18  2012 yorkshire_terrier_71.jpg
# -rwxr-xr-x 1 1001 1001 117K Jun 18  2012 yorkshire_terrier_72.jpg
# -rwxr-xr-x 1 1001 1001 191K Jun 18  2012 yorkshire_terrier_73.jpg
# -rwxr-xr-x 1 1001 1001 110K Jun 18  2012 yorkshire_terrier_74.jpg
# -rwxr-xr-x 1 1001 1001 103K Jun 18  2012 yorkshire_terrier_75.jpg
# -rwxr-xr-x 1 1001 1001 120K Jun 18  2012 yorkshire_terrier_76.jpg
# -rwxr-xr-x 1 1001 1001 108K Jun 18  2012 yorkshire_terrier_77.jpg
# -rwxr-xr-x 1 1001 1001 154K Jun 18  2012 yorkshire_terrier_78.jpg
# -rwxr-xr-x 1 1001 1001 112K Jun 18  2012 yorkshire_terrier_79.jpg
# -rwxr-xr-x 1 1001 1001 132K Jun 18  2012 yorkshire_terrier_7.jpg
# -rwxr-xr-x 1 1001 1001 172K Jun 18  2012 yorkshire_terrier_80.jpg
# -rwxr-xr-x 1 1001 1001 211K Jun 18  2012 yorkshire_terrier_81.jpg
# -rwxr-xr-x 1 1001 1001  73K Jun 18  2012 yorkshire_terrier_82.jpg
# -rwxr-xr-x 1 1001 1001 134K Jun 18  2012 yorkshire_terrier_83.jpg
# -rwxr-xr-x 1 1001 1001 231K Jun 18  2012 yorkshire_terrier_84.jpg
# -rwxr-xr-x 1 1001 1001 144K Jun 18  2012 yorkshire_terrier_85.jpg
# -rwxr-xr-x 1 1001 1001 221K Jun 18  2012 yorkshire_terrier_86.jpg
# -rwxr-xr-x 1 1001 1001 135K Jun 18  2012 yorkshire_terrier_87.jpg
# -rwxr-xr-x 1 1001 1001 107K Jun 18  2012 yorkshire_terrier_88.jpg
# -rwxr-xr-x 1 1001 1001 152K Jun 18  2012 yorkshire_terrier_89.jpg
# -rwxr-xr-x 1 1001 1001 238K Jun 18  2012 yorkshire_terrier_8.jpg
# -rwxr-xr-x 1 1001 1001 134K Jun 18  2012 yorkshire_terrier_90.jpg
# -rwxr-xr-x 1 1001 1001 135K Jun 18  2012 yorkshire_terrier_91.jpg
# -rwxr-xr-x 1 1001 1001 151K Jun 18  2012 yorkshire_terrier_92.jpg
# -rwxr-xr-x 1 1001 1001 106K Jun 18  2012 yorkshire_terrier_93.jpg
# -rwxr-xr-x 1 1001 1001  55K Jun 18  2012 yorkshire_terrier_94.jpg
# -rwxr-xr-x 1 1001 1001 111K Jun 18  2012 yorkshire_terrier_95.jpg
# -rwxr-xr-x 1 1001 1001 156K Jun 18  2012 yorkshire_terrier_96.jpg
# -rwxr-xr-x 1 1001 1001 107K Jun 18  2012 yorkshire_terrier_97.jpg
# -rwxr-xr-x 1 1001 1001 175K Jun 18  2012 yorkshire_terrier_98.jpg
# -rwxr-xr-x 1 1001 1001  84K Jun 18  2012 yorkshire_terrier_99.jpg
# -rwxr-xr-x 1 1001 1001 124K Jun 18  2012 yorkshire_terrier_9.jpg

# %% [markdown]
# # 2. The Convolutional Neural Network
#
# ## Convolutional Neural Networks for scratch
#
# Check the tutorial from reference [[2]](#scrollTo=my1Fk-G5KKmz&line=2&uniqifier=1).
#
# You'll define your convolutional neural network by extending the [torch.nn.Module](https://pytorch.org/docs/stable/generated/torch.nn.Module.html) class, which is the base class for all the neural network modules.
# In the constructor, you define the layers (and their properties) that comprise your module. ``torch.nn`` [package](https://pytorch.org/docs/stable/nn.html) provides classes for the basic layers of a CNN.
#
# The function that you need to override is the _forward()_ function in which you specify computation performed at every call (i.e. how are layers chained and how does the data flow over the computational graph). In other words, this defines the forward pass through your model.

# %%
# TODO your code here: define a simple CNN model, pass a single example through the model

import torch.nn as nn
import torch.nn.functional as F


class Net(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(3, 6, 5)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(6, 16, 5)
        self.fc1 = nn.Linear(16 * 5 * 5, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 10)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = torch.flatten(x, 1) # flatten all dimensions except batch
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x


net = Net()

# %% [markdown]
# ## Transfer learning
#
#
# Check the tutorial from reference [[3]](#scrollTo=my1Fk-G5KKmz&line=2&uniqifier=1).
#
#
# The ``torchvision`` module provides the implementation and pre-trained weights for common neural network architectures.
# For example, to load the resnet18 architecture and its weights (after training on ImageNet, you can use:
#
#
# ```[python]
# from torchvision.models import resnet18, ResNet18_Weights
#
#
# # Using pretrained weights:
# model = resnet18(weights=ResNet18_Weights.IMAGENET1K_V1)
# ```
#
#  Remember from the first lab, that when using a pre-trained model you must preprocess to the image as the images used for training the model. Using the correct preprocessing method is critical and failing to do so may lead to decreased accuracy or incorrect outputs. Each architecture uses a different preprocessing technique, so there is no standard way to achieve this.
#
#
# #### Note (transfer learning training)
#  In the tutorial, you will notice that the authors use model.train() and model.eval() in the training loop. These functions "tell" the model how to act when it is being run. In the next lectures, you will learn that some layers (such as dropout, batch normalization, and so on) behave differently during train and evaluation, and hence the model will produce unexpected results if run in the wrong mode. So don't forget these steps.
#
#
#  To freeze the weights of the model and train only the rest, you can set requires_grad of the parameters you want to freeze to False.
# ```
# for param in model.features.parameters():
#     param.requires_grad = False
# ```
#
#
# On the other hand, the ``torch.no_grad()``context manager that we used in the prvious lab  is used to prevent calculating gradients in the following code block. Usually it is used when you evaluate your model and don’t need to call backward() to calculate the gradients and update the corresponding parameters. In this mode, the result of every computation will have ``requires_grad=False``, even when the inputs have ``requires_grad=True``.

# %%
# TODO : your code here
# get a pretrained torchvision module, change the last layer,  pass a single example through the model

from torchvision.models import resnet18, ResNet18_Weights


# Using pretrained weights:
model = resnet18(weights=ResNet18_Weights.IMAGENET1K_V1)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 65.8MB/s]

# %% [markdown]
# # 3. Training the model
#
#
# For training, we need to define a loss function and an optimizer. We'll cover optimizers next time, in this laboratory we'll just stick to stochastic gradient descent.
#
#
# Let's first define some concepts:
# - epoch: an epoch defines a pass through the entire training dataset. The number of epochs (passes of the entire training dataset the machine learning algorithm has completed) is a hyperparameter of your model. An epoch consists of one or more batches.
# - batch:  a batch defines how many samples your model "sees" before updating its weights. In other words, the batch size is the number of samples that will be passed through to the network at one time during its training.
# - sample: a sample is just a single training example.
#
#
# As you saw in the previous laboratory, a typical training loop looks like this:
# ```
#
#
# optimizer - the chosen optimizer. It holds the current state of the model and will update the parameters based on the computed gradients. Notice that in the constructor of the optimizer you need to pass the parameters of your model and the learning rate.
# criterion - the chosen loss function.
#
#
# for epoch in range(num_epochs):  # num_epochs is a hyperparameter that specifies when is the training process
#
#
#     running_loss = 0.0
#     for i, data in enumerate(dataloader, 0): # iterate over the dataset, now we use data loaders
#         # get a batch of data (inputs and their corresponding labels)
#         inputs, labels = data
#
#
#         # IMPORTANT! set the gradients of the tensors to 0. by default torch accumulates the gradients on subsequent backward passes
#         # if you omit this step, the gradient would be a combination of the old gradient, which you have already used to update the parameters
#         optimizer.zero_grad()
#
#
#         # perform the forward pass through the network
#         outputs = net(inputs)
#
#         # apply the loss function to determine how your model performed on this batch
#         loss = criterion(outputs, labels)
#
#         # start the backprop process. it will compute the gradient of the loss with respect to the graph leaves
#         loss.backward()
#
#
#         # update the model parameters by calling the step function
#         optimizer.step()
#
#
# ```

# %%
# TODO code to train your model

# %%
# TODO code to train your model

# %% [markdown]
# Now let's examine the effect of the learning rate over the training process.
#
# - First, create two plots: one in which you plot, for each epoch, the loss values on the training and the test data (two series on the same graph), and another one in which you plot, for each epoch, the accuracy values on the training and the test data.
# - Experiment with different values for the learning rate.
# - Then, experiment with a torch.optim.lr_scheduler to adjust the learning rate during the training process [doc](!https://pytorch.org/docs/stable/optim.html).
#
# ```
# optimizer = SGD(model, lr)
# scheduler = ExponentialLR(optimizer, gamma=0.9)
#
# for epoch in range(num_epochs):
#     for input, target in dataset:
#         optimizer.zero_grad()
#         output = model(input)
#         loss = loss_fn(output, target)
#         loss.backward()
#         optimizer.step()
#     # apply the learning rate scheduler
#     scheduler.step()
# ```
#
# Plot the learning curves for all the training that you performed.
# Fill in the table to compare the accuracy of your trained models.
#
# | Model              | lr config            | accuracy  train| accuracy test |
# | -----------        | -----------          | ------         | -----         |
# | Model              | lr info              |   acc          |acc            |
# | Model              | lr info              |   acc          |acc            |
#
#
# You can work in teams and each team will train the model with a different setup.

# %% [markdown]
# # Using the GPU
#
# ``torch`` is designed to allow for computation both on CPU and on GPU.
# If your system has a GPU and the required libraries configured for torch compatibility, the cell below will print information about its state.
#
# If you are running your code on colab, you can enable GPU computation from: Runtime->Change Runtime type -> T4 GPU

# %%
import torch
if torch.cuda.is_available():
    # !nvidia-smi
else:
    print("NO GPU ☹️")

# %% [markdown]
# Now we can start to use accelaration.
# You now need to explictly specify on which device your tensors reside. You can
# move all of the model's parameters `.to` a certain device (the GPU)
# and also move the data on the same device there as well
# before applying the model and calculating the loss.

# %%
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
model.to(device)
loss_fn(model(x.to(device)), y.to(device))

# %% [markdown]
# #Useful references
#
# - [1] [a "recipe" ](http://karpathy.github.io/2019/04/25/recipe/)  when you will start training artifcial neural networks;
# - [2] [Defining a CNN](https://pytorch.org/tutorials/beginner/blitz/cifar10_tutorial.html) in torch;
# - [3] [Transfer learning](https://pytorch.org/tutorials/beginner/transfer_learning_tutorial.html) in torch;
# - [4] [model debugging](https://developers.google.com/machine-learning/testing-debugging/common/overview).

# %% [markdown]
# # <font color='red'> Optional </font>
# ## Pooling
#
# The pooling layer is used to reduce the spatial dimension of the activation maps, and thus the computational burden. It has no learnable parameters and it operates individually across each input channel and resizes it spatially.
#
# The two most common types of pooling are max pooling and average pooling.
#
#
# The hyperparameters of a pooling layer are:
# - the filter size F (usually this is an odd value);
# - the stride S (or the step used when sliding across the input volume);
#
# Given an input volume of shape  ($H_i$, $W_i$, $D$), the convolutional layer will produce an output of shape ($H_o$, $W_o$, $D$), where:
#
# \begin{equation}
# W_o = \frac{W_i - F}{S} + 1
# \end{equation}
#
# \begin{equation}
# H_o = \frac{H_i - F}{S} + 1
# \end{equation}
#
# An illustration of the pooling operation is depicted in the image below:
#
# ![picture](https://www.researchgate.net/profile/Alla-Eddine-Guissous/publication/337336341/figure/fig15/AS:855841334898691@1581059883782/Example-for-the-max-pooling-and-the-average-pooling-with-a-filter-size-of-22-and-a.jpg)

# %%
def pooling(X, filter_size, stride, type):
     """
    Implements the pooling operation

    :param X - input volume of shape (num_samples, H, W, C)
    :param filter_size - the size of the pooling
    :param stride - the stride of the pooling operation
    :param type - can be 'max' or 'avg'; the type of the pooling operation to apply

    Returns the output of the pooling operation.
    """
  # TODO your code here implement the pooling operation
  # you can inspire yourself from the convolution implementation on how to organize your code
  pass

# TODO your code here
# apply the pooling operation on a grayscale image and on a color image
# try different values for the stride and filter size. What do you observe?
